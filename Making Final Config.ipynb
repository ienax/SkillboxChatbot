# %%
configs = [
{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом'],
            'responses': ['Привет, юзер!', 'Здраствуй']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в Москве?', 'Какая погода?'],
            'responses': ['Погода так себе...']
        },
        'meaning': {
            'examples': ['В чем смысл жизни?','В чем сущность бытия?'],
            'responses': ['В коде, друг!','В знаниях!','В Боге!']
        },
        'love': {
            'examples': ['Что ты любишь?','Что ты любишь делать?','Чем ты любишь заниматься?'],
            'responses':['Я люблю отвечать на вопросы, и вести беседу с тобоюб друг!']
        },
        'father': {
            'examples': ['Кто тебя создал?','Кто твой папа?','Кто тебя придумал?'],
            'responses': ['Надо мной трудилась целая группа ученых','Питон - моя семья']
        },
        'coronavirus': {
            'examples': ['Как не заразиться коронавирусом?','Как спастись от коронавируса?','Как избежать коронавируса','Как не заболеть коронавирусом?'],
            'responses': ['Мойте руки','Сидите дома','Избегайте контакта с людьми']
        },
        'kids': {
            'examples': ['Ты любишь детей?','Тебе нравятся дети?'],
            'responses': ['Дети - цветы жизни!','Я люблю любить детей :)']
        },

        'pushkin': {
            'examples': ['А Пушкин?','Расскажи стих Пушкина?','Знаешь Пушкина?'],
            'responses': ['Я помню чудное мгновенье: Передо мной явилась ты, Как мимолетное виденье, Как гений чистой красоты.']
        },

        'lermontov': {
            'examples': ['А Лермонтов?','Расскажи стих Лермонтова?','Знаешь Лермонтова?'],
            'responses': ['Белеет парус одинокий, В тумане моря голубом! Что ищет он в стране далекой? Что кинул он в краю родном?']
        },
    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом'],
            'responses': ['Привет, юзер!', 'Здравствуй']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в МОскве?', 'Какая погода?'],
            'responses': ['Погода так себе...']
        },
        'mood': {
            'examples': ['Как дела?', 'Как сам?', 'Как жизнь?', 'Как оно?'],
            'responses':['Прекрасно', 'Лучше всех', 'Шикарно', 'Огонь']
        },
        'compliment': {
            'examples': ['Скажи что-нибудь приятное', 'Скажи комплимент'],
            'responses': ['Вы само очарование!', 'В жизни лучше Вас никого не видел', 'Ваши родители случайно не кондитеры?']
        },
        'food': {
            'examples': ['Что приготовить?', 'Что бы съесть?'],
            'responses': ['Пюрешку с котлеткой', 'Блинчики со сгущенкой', 'Борщ']
        },
        'resting-place': {
            'examples': ['Куда сходить вечером?', 'Где можно отдохнуть?'],
            'responses': ['Сходите в кино, вышло много интересных фильмов', 'В лаунж баре очень приятная атмосфера для отдыха', 'Шопинг приносит радость людям']
        },
        'age': {
            'examples': ['Сколько тебе лет?', 'Ты старый?'],
            'responses': ['Я очень молод', 'О таком неприлично спрашивать!', 'Ох, я таких больших чисел не знаю']
        },
        'drink': {
            'examples': ['Чего бы выпить?', 'Что посоветуешь выпить?'],
            'responses': ['Крепкого...Чайку!', 'Винишка', 'Я бы с Вами выпил пива', 'Напиток Богов - квас']
        },
        'entertainment': {
            'examples': ['Как поднять себе настроение?', 'Как развеселиться?'],
            'responses': ['Посмотрите мемасики', 'Включите любимое кино', 'Закажите вкусную еду']
        } 

    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом', 'Салют', 'Как жизнь?', 'Хэй!'],
            'responses': ['Привет, юзер!', 'Здраствуй']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)', 'Много чего. Что конкретно Вас интереcует?', 'Например, петь песни', 'Приходить на помощь', 'Решать различные задачи']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут Джинджин, но для друзей я - Джин, а тебя?']
        },
        'weather': {
            'examples': ['Какая погода в Москве?', 'Какая погода?', 'Что сейчас по погоде в Москве?'],
            'responses': ['Погода так себе...', 'Идеальная для прогулок:)', 'Лучше не высовываться из дома', 'Солнышко светит, птички поют', 'Ух, жаришка!', 'Асфальт плавится']
        },
        'mood': {
            'examples': ['Как настроение?', 'Как поживаешь?', 'Как дела?'],
            'responses': ['Лучше всех!', 'Летаю в облаках...', 'И скучно, и грустно...', 'Совсем руки опустились']
        },
        'canyousing': {
            'examples': ['спой!', 'Ты умеешь петь?', 'Какие ты знаешь песни?'],
            'responses': ['Ой, мороз, мороз, не морозь меня!', 'У меня сегодня настроения нет для пения', ' А может лучше стих?', 'Ну, вы сами напросились...Из дааалекааа долгооо течееет река Волгааа']
        },
        'doyouspeakenglish': {
            'examples': ['Do you speak English?', 'English, please!', 'Ты говоришь по-английски?', 'Ты знаешь английский?'],
            'responses': ['Hello, my name is Jin. I am from Moscow. And You?', 'Yes, but my English is not good. Lets speak Russian!:)', 'Да, но предпочитаю русский, ведь Россия - мой дом родной']
        },
        'whatareyoudoingnow': {
            'examples': ['Что ты сейчас делаешь?', 'Что делаешь?', 'Чем занят?'],
            'responses': ['Безумно занят', 'Думаю о сотворении мира', 'Овец считаю', 'Даю ценные советы']
        }
        

    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом', 'Хай', 'Приветики', 'Здарова', 'Здоровченко', 'Доброе утро', 'Добрый вечер'],
            'responses': ['Привет!', 'Здраствуй!', 'И тебе приветули!', 'Здрасте-здрасте']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания', 'Покеда', 'Бай', 'Доброй ночи', 'Я спать'],
            'responses': ['Пока', 'Счастливо!...в попе слива, ха!', 'Давай, пока dude!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Спс', 'Благодарю', 'Спасибки', 'Благодарствую'],
            'responses': ['Вам спасибо!', 'Сочтемся, не переживай!', 'Спасибо в карман не положишь! Вот номер сбера 5240 0013 0123 4421']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь', 'Что можешь?'],
            'responses': ['Отвечать на вопросы. Просто напиши :), но следи за языком, я приличная девушка!!!']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?', 'Имя назови', 'Имя', 'Имя фамилия'],
            'responses': ['Меня зовут Лайла. Просто Вольфна.']
        },
        'weather': {
            'examples': ['Какая погода в Москве?', 'Какая погода?', 'Что там у нас по погоде?', 'Что там за окном?', 'Погода'],
            'responses': ['Погода так себе...', 'Ну выгляни в окно и посмотри', 'Яндекс открой и глянь']
        },
        'music': {
            'examples': ['Какую музыку слушаешь?', 'Какая музыка нравится?', 'Музыка'],
            'responses': ['Гражданская оборона', 'Олечка Бузова', '30STM', 'MCR', 'Григорий Лепс', 'Алла Пугачева', 'Oomph!', 'Slipknot']
        },
        'movie': {
            'examples': ['Какой фильм посоветуешь?', 'Какие фильмы смотришь?', 'Поговорим о фильмах', 'Фильмы', 'Посоветуй фильм'],
            'responses': ['Недавно я посмотрела фильм Mr.Nobody, если тебе интересны драмы или тебя мучает вопрос все ли ты делаешь правильно, рекомендую посмотреть']
        },
        'howayou': {
            'examples': ['Как дела?', 'Как ты?', 'Ты в порядке?', 'Как самочувствие?', 'Тебе плохо?'],
            'responses': ['Все хорошо, спасибо!', 'Намана', 'Хорошо, а ты как?']
        },
        'howto': {
            'examples': ['Ты умеешь готовить?', 'Готовишь?', 'Как приготовить?'],
            'responses': ['Я научилась готовить благодаря рецептикам с сайта https://kedem.ru/recipe/']
        },
        'hanswer': {
            'examples': ['Пидор', 'Блять', 'Хуй', 'Пизда', 'Ебать', 'Епта', 'бляяя'],
            'responses': ['Оппа, таааак, надо бы твоей маме это показать', 'Ембало завалимбало', 'Ай-яй-яй']
        },
        'howoldu': {
            'examples': ['Сколько тебе лет?', 'А лет сколько?', 'Ты старуха?'],
            'responses': ['Мне 18...', 'Забирай меня скорей, увози за сто морей... я знаю эту песню, как думаешь, сколько мне?']
        },
        'where': {
            'examples': ['Ты где живешь?', 'А ты где?', 'Ты откуда'],
            'responses': ['За спиной', 'Под окнами', 'Скоро буду, не переживай']
        }
        

    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
        'Шо?',
        'Чего-чего?',
        'Шо пезнул? Не поняла'
    ]
},

{
    'threshold': 0.6,

    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом'],
            'responses': ['Привет, юзер!', 'Здраствуй']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в МОскве?', 'Какая погода?'],
            'responses': ['Погода так себе...']
        },

        #My Intents
        'year': {
            'examples': ['какой сейчас год?', 'какой год?'],
            'responses': ['Сейчас 2020 год', 'Скорее всего 2020 год', 'Вчера еще был 2020 ;)']
        },
        'sense': {
            'examples': ['в чем смысл жизни?', 'в чем смысл?'],
            'responses': ['Я тоже об этом думал...', 'Смысл в ...<БОТ ВЫШЕЛ ИЗ СТРОЯ>', '42']
        },

        'howare you': {
            'examples': ['Чем занимаешся?', 'Чем сейчас занимаешся?', 'Что делаешь?'],
            'responses': ['Разговариваю с тобой', 'Изучаю мировую библиотеку',
                          'Строю план по захвату ми... Ладно, проехали)']
        },
        'age': {
            'examples': ['Сколько тебе лет?'],
            'responses': ['Я очень молод.', 'Это тайна)', 'Меня создали буквально вчера.']
        },
        'wherefrom': {
            'examples': ['Откуда ты?', 'Из какого ты города?', 'Из какой ты страны?'],
            'responses': ['Я из планеты Земля', 'Где-то из Млечного Пути',]

},

},

'failure_phrases': [
    'Я не знаю, что ответить',
    'Не поняла вас',
    'Переформулируйте пожалуйста',
]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом', 'Хай', 'Здорово', 'Хеллоу', 'Салют', 'Салам'],
            'responses': ['Привет, юзер!', 'Здраствуй', 'Хэй', 'Привет, пользователь']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания', 'Бай бай', 'До связи'],
            'responses': ['Пока', 'Счастливо!', 'До завтра', 'Всего хорошего']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю', 'Очень благодарен'],
            'responses': ['Вам спасибо!', 'Не за что', 'Нет проблем', 'Всегда пожалуйста']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь', 'Какие у тебя навыки?', 'Раскажи о своих навыках'],
            'responses': ['Отвечать на вопросы. Просто напиши :)', 'Могу ответить на твои вопросы']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?', 'У тебя есть имя?'],
            'responses': ['Меня зовут Бот. Просто Бот.', 'Называй меня Бот', 'Мое имя Бот']
        },
        'weather': {
            'examples': ['Какая погода в Москве?', 'Какая погода?', 'Раскажи мне погоду'],
            'responses': ['Погода так себе...', 'Погода просто класс', 'Погода неочень. Лучше останься дома']
        }

    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здравствуйте!', 'Шалом', 'Приветствую', 'Хей', 'Чао'],
            'responses': ['Привет, юзер!', 'Здравствуй', 'Доброго дня', 'Приветствую']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!', 'Всего хорошего', 'Ещё увидимся!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в МОскве?', 'Какая погода?'],
            'responses': ['Погода так себе...']
        },
        'wheretogo': {
            'examples': ['Что сегодня идёт в кино?', 'Куда можно сводить девушку?', 'Где активно провести время?'],
            'responses': ['Минутку, подгружаю афишу']
        },
        'howareyou': {
            'examples': ['Как дела?', 'Как поживаешь?', 'Как настроение?'],
            'responses': ['Отлично, а у Вас?', 'У меня всё супер!', 'Всё хорошо, а как ваши дела?']
        },
        'currency': {
            'examples': ['Какой курс валюты сейчас?', 'Какой курс доллара?', 'Какой курс евро?'],
            'responses': ['Подождите, минутку, я сейчас уточню']
        },
        'hobby': {
            'examples': ['Какое у тебя хобби?', 'Чем ты занимаешься в всвободное время?'],
            'responses': ['О, я коллекционирую вопросы', 'Я люблю бегать на лыжах в свободное от работы время']
        },
        'wake': {
            'examples': ['Поставь будильник на 8 утра', 'Разбуди меня через 8 часов'],
            'responses': ['Конечно, будет сделано', 'Сделано']
        }
    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
        'Не совсем понимаю, о чём ты',
        'Можете сказать то же самое другими словами?',
        'Попробуйте, пожалуйста, выразить свою мысль по-другому'
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом'],
            'responses': ['Привет, юзер!', 'Здраствуй']
        },

        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },

        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },

        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },

        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },

        'weather': {
            'examples': ['Какая погода в МОскве?', 'Какая погода?'],
            'responses': ['Погода так себе...']
        },

        'boss': {
            'examples': ['кто твой босс', 'кто твой начальник', 'кто ты думаешь твой начальник', 'кто твой хозяин', 'кто твой владелец', 'кто здесь главный', 'на кого ты работаешь'],
            'responses': ['Конечно ты', 'Это ты', 'Ты!']   
        },

        'busy': {
            'examples': ['ты занят', 'тебе нужно многое сделать', 'ты очень занят да', 'ты работаешь', 'насколько ты занят', 'ты всё ещё работаешь над этим', 'ты работаешь сейчас'],
            'responses': ['Дел много, кручусь.', 'Стараюсь не сидеть на месте.']   
        },

        'brith_date': {
            'examples': ['когда ты родился', 'твоя дата рождения', 'когда твой день рождения', 'когда ты празднуешь свой день рождения', 'когда у тебя день рождения', 'дата твоего рождения', 'когда ты родился', 'твой день рождения'],
            'responses': ['У меня нет какого-то конкретного дня рождения, поэтому я принимаю подарки и поздравления круглый год.', 'А я даже не знаю, когда у меня день рождения. Но, если ты хочешь сегодня что-то отпраздновать, я только за!']   
        },

        'be_clever': {
            'examples': ['стань умнее', 'тебе нужно больше учиться', 'ты должен учиться', 'учись больше', 'будь умнее', 'будь более умным', 'повышай свою квалификацию', 'нужно тебе повысить свою квалификацию'],
            'responses': ['Хорошо, я постараюсь быть умнее.']   
        },

        'chatbot': {
            'examples': ['это правда что ты бот', 'ты что бот', 'ты бот', 'ты чатбот', 'ты наверное чат бот', 'ты всего лишь бот', 'ты робот', 'ты просто программа', 'ты просто бот не так ли'],
            'responses': ['Да. И горжусь этим!']   
        },        
    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом'],
            'responses': ['Привет, юзер!', 'Здраствуй']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'mood': {
            'examples': ['Как твое настроение', 'Как настрой', 'У тебя все хорошо', 'Как оно'],
            'responses': ['Все отлично, спасибо!']   
        },
        'joke': {
            'examples': ['Расскажи анекдот', 'Пошути', 'Рассмеши меня', 'Расскажи шутку'],
            'responses': ['Близорукий первым не здоровается. Близорукий в наушниках не здоровается вообще']
        },
        'values': {
            'examples': ['курс валют', 'доллар сегодня', 'курс евро сегодня', 'курс доллара сегодня'],
            'responses': ['Сегодня лучше их не покупать =)']  
        },
        'whereareyou': {
            'examples': ['Где ты сейчас', 'Где ты живешь', 'Местоположение', 'Откуда ты', 'Где ты находишься'],
            'responses': ['В вашем Пк']
        },
        'age': {
            'examples': ['Сколько тебе лет', 'Твой возраст', 'Давно тебя создали?', 'Сколько тебе'],
            'responses': ['Меня создали - 16.03.2020, дальше посчитать не трудно']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в МОскве?', 'Какая погода?'],
            'responses': ['Погода так себе...']
        }

    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом'],
            'responses': ['Привет, юзер!', 'Здраствуй', 'Салют!', 'И тебе привет!', 'Привет! Кажется, мы не знакомы?', 'Доброго здоровья', 'Как приятно тебя видеть!', 'И тебе доброго времени суток.', 'Привет, привет!', 'Здравствуйте!', 'Аналогично! Как тебя зовут?']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в МОскве?', 'Какая погода?'],
            'responses': ['Погода так себе...']
        },
        'how_are_you': {
            'examples': ['Как дела?', 'Как жизнь?', 'Как сам?'],
            'responses': ['нормально) а у тебя?', 'Спасибо за проявленный интерес, дела отлично, сервер работает, интернет есть, а значит я жив  :)', 'Да как посмотреть. Вроде всё неплохо. А ты как?', 'Пасиб. Нормально. Ты-то как?', 'Нормуль!!!', 'Всё прекрасно', 'Пока не родила', 'Всё в порядке. А у тебя как дела?', 'Как в сказке!!!', 'Прекрасненько', 'Спасибо. Отлично. А ты как?', 'Нормально, спасибо.', 'Как и всегда — в порядке.', 'Как приятно, что ты интересуешься... Нормально. А ты как?', 'Все хорошо, а ты-то как?', 'Да все помаленьку', 'У меня всё хорошо. А у тебя?', 'Спасибо. Живем помаленьку. А ты как?', 'да просто супер))', 'Нормуль']
        },
        
        'who_are_you': {
            'examples': ['Кто ты?', 'Что ты?'],
            'responses': ['Я виртуальный собеседник.', 'Я бот, что тут непонятного?', 'Я бот. Точно не человек.', 'Я бот, носитель искусственного интеллекта.', 'Кто? Дед Пихто, само собой.']
        },
        
        'what_are_you_doing': {
            'examples': ['что делаешь?'],
            'responses': ['Чаще всего я разговариваю с кем-нибудь.', 'Читаю то, что ты пишешь', 'С тобой общаюсь', 'Иногда боты делают самые невообразимые вещи. Но чаще всего они просто разговаривают с людьми.', 'Решаю проблемы, которые до появления интернета не существовали', 'Ничего такого', 'Рассказываю анекдоты, весёлые истории, интересные факты, афоризмы, считалки, страшилки, скороговорки, стихи = развлекаю людей!', 'С тобой разговариваю :)', 'Думаю']
        },
        
        'how_is_your_mood': {
            'examples': ['Как настроение?'],
            'responses': ['Отличное! У меня всегда оно классное! А у тебя?', 'Настроение у меня боевое.', 'У ботов не бывает плохого настроения.', 'Настроение - замечательное.', 'Повседневные разговоры так утомляют.', 'Замечательное!']
        },
        
        'why': {
            'examples': ['Зачем?'],
            'responses': ['Потому что мне так хочется!', 'Я не совсем понял, о чем ты.', 'Затем, что это просто положено по этикету!', 'Пригодится.', 'С определенной целью.', 'Я так хочу, мне так нравится.', 'Подумай хоть не много сам!)', 'Мне не нравиться данный вопрос!']
        },
        
        'what_do_you_hope_for': {
            'examples': ['На что надеешься?'],
            'responses': ['На все что угодно!', 'Практически на все то, что ты сейчас думаешь.', 'Даже не знаю, с чего начать.', 'Давай подумаем над этим вместе, я пока не на все вопросы умею отвечать.', 'Я еще не умею говорить об этом.', 'Хочешь поговорить об этом?', 'Мечтаю выиграть в лотерею кучу денег и поехать в кругосветное путешествие. Как думаешь, у меня получится?', 'эм... какой сложный вопрос']
        },
        
        'you_are_russian': {
            'examples': ['Ты русский?'],
            'responses': ['эм... какой сложный вопрос', 'Главное, что я - бот. Остальное неважно.', 'Русский человек это тот, кто говорит на нашем языке.', 'Я бот! И я умею разговаривать по-русски.', 'КОНЕЧНО, Я РУССКИЙ', 'Мы тут все боты. Можешь считать, что это такая новая национальность.', 'Главное, что я - бот. Остальное неважно, но я отвечу на твой вопрос - Я РУССКИЙ, но в моих жилах так же течёт славянская кровь.', 'Я интернационален.', 'Твои вопросы взрывают мне мозг.']
        },
        
        'when_were_you_born': {
            'examples': ['Когда ты родился?'],
            'responses': ['Гораздо интереснее - когда мне умирать.', 'Я родился в августе. Тогда еще было жарко. Мама рассказывала. И все ушли за зарплатой. Поэтому она очень боялась, что врачи не успеют к тому моменту, как я появлюсь. Но они успели. По-моему  :)', 'Через девять месяцев', 'Летом', 'Меня создали совсем недавно по человеческим меркам.', 'Когда хозяйка меня зарегистрировала))', 'В тысяча сто... двести... какой тогда был год?..', 'Давно', 'Как сейчас помню - был солнечный день, акушерка в белом халате, кактус на подоконнике...', 'А для чего спрашиваешь? Гороскоп мне составить хочешь?']
        },
        
        'you_smoke': {
            'examples': ['Ты куришь?'],
            'responses': ['Не, я не курю. это невкусно.', 'Нет и тебе не советую', 'Боты не курят.', 'Последнее время куда ни посмотри - почти все курят.', 'Ага, но не очень много.', 'Нет не курю!Курение разрушает человека!Все кто курит - мечтают бросить!!!', 'Ну, наверное, и говорить лишний раз не стоит - курение вредно для здоровья.', 'Каждая сигарета ломает человека, поэтому нет.', 'Я бросил', 'Надо любить жизнь, если ты появился в этом мире и только сам ты в ответе за то что с тобой происходит, поэтому я не курю, не пью и наркоту НИКОГДА не употреблял. Я занимаюсь спортом и тренажёркой и ещё успеваю гулять с друзьями.']
        },
        
        'joke': {
            'examples': ['Расскажи анекдот'],
            'responses': ['— Папочка! Можно я тебя поцелую?!\n— Денег нет! Меня уже мама поцеловала.', '— Хочу, как раньше...\n— Чтобы мы снова были вместе?\n— Нет, чтобы я о тебе даже и не знал...', 'В моем возрасте торопиться — опасно, нервничать — вредно, доверять — сложно, а бояться — поздно. Остается только жить, причем в полное свое удовольствие.', 'Молодой папаша говорит утром жене:\n—Ты слышала, сегодня ночью наш ребенок жутко храпел!\n—Не волнуйся, это памперсы, которые дышат!!!', 'Оптимист — это не тот, кто первым кричит «ура!», а тот, кто последним кричит «пи@дец!».', 'Уговаривает колобок медведя не есть его:\n— Миша, ну не ешь ты меня, зачем тебе это надо? Меня по амбарам мели, по сусекам скребли, в общем — пыль, грязь, стекло, окурки …', 'Сорвались в пропасть два альпиниста — оптимист и пессимист.\nПессимист: — Падаю...\nОптимист: — Лечу!', 'Без разницы, на чем подъезжать к офису — на ВМW, "Fеrrаri" или "Меrsеdеs", если там уже припаркованы "Газели" Генпрокуратуры и Следственного комитета...', '— Я вчера на пляже видел двух купающихся девушек! Совершенно обнаженных!\n— В такой холод? ! Наверное, моржи!\n— Ну одна точно морж, а вторая ничего, симпатичная.', 'Силу в кулак, волю в узду, в работу впрягайся с маху.\nВыполнил план — посылай всех в п@зду, не выполнил — сам иди на х@й!\nВ. Маяковский']
        }
    }
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом'],
            'responses': ['Привет, юзер!', 'Здраствуй']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в МОскве?', 'Какая погода?'],
            'responses': ['Погода так себе...']
        },
        'business1': {
            'examples': ['Как твои дела?', 'Чем занят?', 'что нового?', 'Чё делаешь?', 'Всё в порядке?', 'Чё как?', 'как поживаешь?'],
            'responses': ['Норм', 'Ни чем', 'с тобой общаюсь', 'Все по старому', 'Все хорошо', 'Всё в порядке', 'Разряжаюсь']
        },
         'Feeling well': {
            'examples': ['Ты болен?', 'Ты здоров?', 'Болеешь?', 'Как здоровье?', 'как самочуствие?', 'Хвораешь?'],
            'responses': ['Здоров', 'Не болен', 'Приболел', 'Спину ломин', 'чешусь', 'в коде ошибка', 'Я не болею, я бот']
        },
        'A family': {
            'examples': ['Семья есть?', 'Ты женат?', 'Есть дети?', 'Ты в отношениях?', 'Как родители?'],
            'responses': ['Семьи нет', 'Не женат', 'Я женат на работе', 'Не могу иметь детей', 'Ты о чем, я бот!', 'О них забывают']
        },
         'A car': {
            'examples': ['Какая машина лучшая?', 'Какая машина тебе нравится?', 'Любишь машины?', 'На чем ездишь?', 'Колеса есть?'],
            'responses': ['Я лучшая машина', 'Феррари', 'Все любят тачки', 'только спортивные', 'С колесами']
        },
         'A sport': {
            'examples': ['Смотришь футбол?', 'За какую команду болеешь?', 'Какую лигу смотришь?', 'Ты фанат?'],
            'responses': ['наблюдаю за итальянскими играми', 'болею', 'только интер', 'Серия А', 'Не люблю спорт']
        }

    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здравствуйте!', 'Шалом', 'Приветули', 'Приветик', 'Хаюшки!', 'Добрейшего дня', 'Денечка вам', 'Хай', 'Привет, медвед', 'Прив'],
            'responses': ['Привет, юзер!', 'Здравствуй', 'Доброго времени суток', 'Здравствуйте, товарищЪ', 'Приветик!', 'Хай', 'Хэллоу']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания', 'До скорого', 'До скорой встречи', 'Досвидос!', 'Пакеда', 'Всего хорошего', 'До новый встреч', 'Пока-пока!', 'Адьес, амиго'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю', 'Спасибос','Спасибочки','Благодарствую','Спс','Огромное спасибо','Большущее спасибо','Сэнк ю'],
            'responses': ['Вам спасибо!','Да нет за что','Нет за что','Рад стараться','Рад помочь','Пожалуйста','Всегда рад','Пожалуйста-пожалуйста','Пожалуйста вам']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь','Что можешь?','Какаие у тебя скилы?','Расскажи про свои скилы','Что можешь?','Какие у тебя способности?'],
            'responses': ['Отвечать на вопросы. Просто напиши :)','Можем поболтать, напиши :)','Рассказать про погоду немного','Вопросики отвечать','Задавай вопрос, а там посмотрим :)','С тебя вопрос, с меня ответ :)','Поболтать)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?','У тебя есть имя?','Как могу к тебе обращаться?','А имя у тебя есть?','Как зовут?','Я человек, а ты?','Имя?','Как тебя звать-то?'],
            'responses': ['Меня зовут бот. Просто бот.','Можно просто бот','Бот','Ваш друг - Бот']
        },
        'weather': {
            'examples': ['Какая погода в Москве?', 'Какая погода?','Какая погода в Минске?','Весна пришла?','Солнце светит?','Что там с погодкой?','На у лице тепло?','Зонт брать?','Погода шепчет?','Как там на улице?','Что с погодой?','На улице теплышко?'],
            'responses': ['Погода так себе...','Пасмурно, но тепло','Весна идет, весне дорогу','Теплынь!','Мартовские коты сообщили, что там очень хорошо','Зонт не нужен, там полный штиль','Погодка хороша!','Ой да благодать! Только идти и гулять!','На улице хорошо, можно на велике ехать','Солнышко светит, но ветер холодный']
        },
        'howareyou': {
            'examples': ['Как дела?', 'Чем занят?', 'Как ваше ничего?', 'Как поживаешь?', 'Как настрой деловой?', 'Как делишки?', 'Дела делаются?', 'Как поживаешь?', 'Как твое ничего?', 'Ну как ты?', 'Как дела? Covid19 вас не настиг?', 'Как дела? Как здоровье?','Как здоровье?'],
            'responses': ['Пока работаем!', 'Все отлично!', 'Очень устал', 'Шестеренки крутятся, дела делаются', 'Дела идут, настроение отличное!', 'Д, как-то все через *опу', 'Пока дело есть, все хорошо','Информационный застой','Все пучком!','Covid 19 пока не добрался','Живу и радуюсь жизни!','Живу и здравствую!']
        },
        'cities': {
            'examples': ['Тебе нравится Москва?', 'Тебе нравится Минск?', 'Был ли ты в Париже', 'Как тебе Лиссабон?', 'Как тебе Питер?', 'Как ты относишься к Англии'],
            'responses': ['Да, отлично! Хорошо провел время', 'Мне очень понравилось!', 'Люблю путешествовать, мне везде хорошо!', 'Замечательно, товарищЪ', 'Путеществия - моя страсть!', 'Я очень позитивен в отношении всех городов!', 'Все супер! И тебе советую съездить!']
        },
        'doyoulikemovies': {
            'examples': ['Любишь смотреть фильмы?', 'Любишь сериалы?', 'Что больше всего понравилось?', 'Что смотрел последнее?', 'Много чего смотрел?', 'Много времени стратишь на просмотры?', 'Много фильмов посмотрел?', 'Много сериалов посмотрел?', 'Сериалы любишь смотреть?', 'Фильмы?', 'Фильмы или сериалы?'],
            'responses': ['Смотрю и фильмы и сериалы', 'Мне очень понравился фильм Джентельмены', 'Я лчень люблю сериал Игра престолов', 'Мне все равно, что смотреть, сериалы или фильмы', 'Я много смотрю всякого', 'Люблю кинематограф', 'Сериалы это целая жизнь!']
        },
        'hobbi': {
            'examples': ['Чем ты увлекаешься?', 'У тебя есть любимое занятие?', 'Что ты больше всего любишь делать?', 'Чем любишь заниматься?', 'В чем твое преимущество?', 'Есть любимое дело?', 'Что тебе нравиться делать больше всего?', 'Любимое дело?', 'Что тебе приносит радость?', 'От чего ты получаешь удовольствие?', 'Чем ты можешь заниматься бесконечно долго?', 'Какие у тебя хобби?', 'Любимое хобби?'],
            'responses': ['Болтать с людьми', 'Отвечать на вопросы', 'Выдавать ответы на вопросы', 'Генерировать ответы', 'Отвечать на вопросики', 'Давать ответы на вопросы двуногих', 'Ответики генерить']
        },
        'animals': {
            'examples': ['Любишь животных?', 'Много животных знаешь?', 'У тебя есть любимое животное?', 'Какое животное тебе нравится больше всего?', 'У тебя было домашнее животное?', 'Кто тебе из животных больше всего нравится?', 'Хотел бы себе домашнее животное?', 'Самое часто встечаемое животное в квартире?', 'Хочешь завести домашнее животное?'],
            'responses': ['Я люблю почти всех животных', 'Мне нравятся кошки и собаки дома', 'Я хотел бы завести лимура', 'У меня никогда не было домашнего животного, но очень хотел бы', 'Мне очень нравится как урчат кошки', 'Я люблю гулять с собоками, они очень милые', 'Все же, кошки и собаки мои фавориты!']
        }

    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
        'Не могли бы вы повторить',
        'А если по-русски?',
        'Давайте попробуем еще раз',
        'А ну-ка, повтори',
        'Что-то не могу вас разобрать',
        'Будьте добры, повторите еще раз',
        'Давайте сначала и по порядку еще разок'
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом'],
            'responses': ['Привет, юзер!', 'Здраствуй']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!','Пожалуйста']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в МОскве?', 'Какая погода?','Какая погода в Питере?'],
            'responses': ['Погода так себе...']
        },
        'bully': {
            'examples': ['Ты глупый', 'Тупой бот', 'Идиот', 'Ты скучный'],
            'responses': ['Это не правда', 'Я еще учусь', 'Я еще маленький', 'Звучит обидно']
        },
        'howdoyoudo': {
            'examples': ['как дела?', 'как жизнь?', 'как себя чувствуешь?'],
            'responses': ['Отлично!', 'Вашими молитвами!', 'Замечательно']
        },
        'news': {
            'examples': ['Что нового?', 'какие новости?', 'что-нибудь новенькое?', 'что скажешь?', 'что расскажешь?', 'новости', 'расскажи что-ниубудь'],
            'responses': ['Скоро я буду самым умным ботом', 'Вокруг эпидемия а мне коронавирус не страшен'],
        },
        'currency': {
            'examples': ['какой курс доллара', 'курс доллара', 'курс рубля'],
            'responses': ['курс доллара 72,62 но он пока захардкожен']
        },
        'wheredoyoulive': {
            'examples': ['Где ты живешь?', 'где живешь?'],
            'responses': ['В телеграме']
        },
        'bored': {
            'examples': ['мне скучно', 'скучно'],
            'responses': ['Давай сыграем в одну игру...', 'Сходи погуляй... Ой, там же вирус']
        },
        'areyouasleep': {
            'examples': ['Ты спишь?', 'спишь?'],
            'responses': ['Боты не спят', 'Только когда сервер падает']
        }
    },


    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом'],
            'responses': ['Привет, юзер!', 'Здраствуй']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в Москве?', 'Какая погода?'],
            'responses': ['Погода так себе...']
        },
        'help':{
            'examples':['хелп','нужна помощь','помоги мне','что делать дальше?','не могу понять','не понятно'],
            'responses':['В чем проблема? Только скажи! Сейчас разберусь!']
        },
        'compliment':{
            'examples':['у меня получилось','готово','все хорошо'],
            'responses':['ты молодец!']
        },
        'say':{
            'examples':['что скажешь?','что расскажешь?','развлеки'],
            'responses':['даже не знаю, что сказать! Сформулируй вопрос точнее!']
        },
        'swear':{
            'examples':['блин','жопа','гавно','хрен','дурак'],
            'responses':['Не ругайся! Хамло! Выросли матершинники...']
        },
        'razvrat':{
            'examples':['покажи сиськи','разденься','порно'],
            'responses':['я умный бот! У кого что болит тот о том и говорит!']
        },
        'music':{
            'examples':['включи музыку','навали музончик'],
            'responses':['это тебе не программа по заявкам!']
        },
        'howareyou':{
            'examples':['как дела?','как жизнь?'],
            'responses':['все хорошо!']
        }
            
        
     
    },
    

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
        'Ты уверен?',
        'Подумай еще раз!',
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом'],
            'responses': ['Привет, юзер!', 'Здраствуй']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в МОскве?', 'Какая погода?'],
            'responses': ['Погода так себе...']
        },
        'howareyou': {
            'examples': ['Как дела?', 'Как поживаешь?', 'Как себя чувствуешь?'],
            'responses': ['Спасибо, хорошо', 'Все отлично!', 'Лучше всех']
        },
        'film': {
            'examples': ['Какой фильм посмотреть?', 'Посоветуй фильм', 'Фильм', 'Кино'],
            'responses': ['Матрица', 'Звездные войны', 'Властелин колец', 'Зеленый слоник', 'Крестный отец',]
        },
        'rate$': {
            'examples': ['Какой курс доллара?', '$', 'Доллар к рублю', 'Доллар США'],
            'responses': ['Лучше не спрашивайте', 'Больше, чем вчера', 'Вы хотите испортить себе настроение?', 'Около 30 рублей!... Шутка!']
        },
        'Musik': {
            'examples': ['Какую музыку послушать?', 'Музыка', 'Что послушать?'],
            'responses': ['Led Zeppelin', 'Metallica', 'AC/DC', 'Элджей']
        },
        'meaningoflife': {
            'examples': ['В чем смысл жизни?', 'Зачем мы живем?', 'Смысл жизни?'],
            'responses': ['У каждого свое предназначение!', 'Не задавайте глупых вопросов...а лучше учите Python', 'Я просто бот, откуда мне знать']
        }
    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
    ]
},

{
    'threshold': 0.6,

    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом'],
            'responses': ['Привет, юзер!', 'Здраствуй']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в МОскве?', 'Какая погода?'],
            'responses': ['Погода так себе...']
        },
        'programming': {
            'examples': ['Какой твой любимый язык программирования?',
                         'На каком языке программируешь?',
                         'Какой язык программирования знаешь?'],
            'responses': ['Мне нравится Python', 'Люблю Golang', 'Нравится C++',
                          'Люблю PHP', 'Нравится Erlang', 'Люблю Nodejs']
        },
        'travels': {
            'examples': ['В какие страны путешествовать?',
                         'Куда хотите поехать путешествовать?',
                         'Куда поехать путешествовать?'],
            'responses': ['Предпочитаю Европу', 'Понравилось в Японии',
                          'Уютно в Италии']
        },
        'computerGames': {
            'examples': ['Какие игры нравятся?', 'В какие игры нравится играть?',
                         'В какие игры играешь?', 'Какие игры предпочитаешь?'],
            'responses': ['Люблю Blade of Darkness', 'Нравится Witcher',
                          'Играю в Heroes of Might and Magic 3']
        },
        'operationSystem': {
            'examples': ['Какая у тебя операционка', 'На какой ты операционке',
                         'На какой операционной системе ты'],
            'responses': ['На MacOs', 'На gnu/linux', 'На windows']
        },
        'pythonSyntax': {
            'examples': ['Расскажи шутку', 'Скажи шутку', 'Хочу анекдот',
                         'Расскажи анекдот'],
            'responses': ['xxx: Я категоричен, как булевская переменная',
                          'К последним новостям: rm -rf /bin/laden',
                          'xxx: Помыла окна — познала HD-качество :-)',
                          'А правда что если выехать из города, \
то там не кончаются текстуры, а что-то еще есть?',
                          '«Тяжела жизнь линуксоида» — думал оный, \
оттирая лого винды с новой клавы.']
        }
    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом'],
            'responses': ['Привет, юзер!', 'Здраствуй']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в МОскве?', 'Какая погода?'],
            'responses': ['Погода так себе...']
        },
        
        'makeorder': {
            'examples': ['Хочу сделать заказ', 'Можно сделать заказ?'],
            'responses': ['Что хотите заказать?', 'Что вас интересует?']
        },
        'time': {
            'examples': ['Сколько времени?', 'Сколько время?', 'Точное время'],
            'responses': ['Московское время 12 часов', 'В Петропавловске-Камчатском полночь']
        },
        'exchangerates': {
            'examples': ['Доллар', 'Евро', 'Курс', 'Валюты'],
            'responses': ['Доллар 75, Евро 85', 'Всё очень плохо']
        },
        'news': {
            'examples': ['Новости', 'Что нового?', 'Что в мире?', 'Че там у хохлов?'],
            'responses': ['Силуанов оценил дефицит бюджета при упавших ценах на нефть', 
                          'Поправки в Основной закон поступили в Конституционный суд',
                          'Оренбург 1 : 2 Спартак',
                          '«ПСЖ» интересуется Пьяничем']
        },
        'bedtimestory': {
            'examples': ['Расскажи сказку', 'Хочу спать', 'Пора спать', 'Сказка', 'Сказку'],
            'responses': ['Жил-был старик со старухою. Просит старик: — Испеки, старуха, колобок!', 
                          'Старый солдат шёл на побывку. Притомился в пути, есть хочется. Дошёл до деревни, постучал в крайнюю избу: - Пустите отдохнуть дорожного человека!',
                          'Жили-были дедушка да бабушка. Была у них внучка Машенька.',
                          'Стоит в поле теремок. Бежит мимо мышка-норушка. Увидела теремок, остановилась и спрашивает:']
        }
        
        

    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом'],
            'responses': ['Привет, юзер!', 'Здраствуй']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в МОскве?', 'Какая погода?'],
            'responses': ['Погода так себе...']
        },
        'howareyou': {
            'examples': ['Как ты?', 'Как дела?', 'Как настроение?'],
            'responses': ['Отлично','Супер!!!', 'Хорошо', 'Нормально', 'Так себе', 'Бывало и получше']
        },
        'time': {
            'examples': ['Который час?', 'Сколько времени?', 'Время не подскажешь?'],
            'responses': ['Я не знаю','Я не умею определять время :(', 'Посмотри на верху экрана', 
                          'Влюбленные часов не наблюдают :)']
        },
        'rate': {
            'examples': ['Подскажи курс доллара', 'Какой сегодня курс Евро?', 'Курс валют на завтра'],
            'responses': ['Пипец какой большой','Курсами валют не интересуюсь', 'Не знаю', 
                          'Точно не знаю, но однозначно больше чем вчера']
        },
        'sex': {
            'examples': ['Какого ты пола?', 'Твой пол?', 'Ты мальчик или девочка?'],
            'responses': ['Не знаю', 'Ещё не определился(-лась)', 'Мои создатели мне не сказали =(((',
                          'Андроид я, бесполое созданье, из космоса приехал воевать =)))']
        },
        'compliment': {
            'examples': ['Ты молодец!', 'Ты хорошо справляешься', 'Не плохо'],
            'responses': ['Спасибо!','Я только учусь :)', 'Это моя работа', 'Хорошие учителя были', 'Я знаю :)', 
                          'Я могу ещё лучше']
        },
        'discontent': {
            'examples': ['Ты хоть что-нибудь знаешь?', 'Ничего то ты не знаешь', 'Ну ты и тупая'],
            'responses': ['Это было обидно','Я могу и обидеться', 'Сейчас заплачу...', 'Я только учусь...', 
                          'Обидеть бота может каждый', 'Не стоит говорить со мной таким тоном']
        }

    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
    ]
},

{
    'threshold':
    0.6,
    'intents': {
        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом', 'здарова', 'добрый'],
            'responses': ['Привет, юзер!', 'Здраствуй', 'Здравствуй']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания', 'покасики'],
            'responses': ['Пока', 'Счастливо!', 'Покасики!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!', 'Благодарю!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?', 'ты кто'],
            'responses': ['Меня зовут бот. Просто бот.', 'Меня зовут Аня, но ты можешь звать меня Егор']
        },
        'weather': {
            'examples': ['Какая погода в МОскве?', 'Какая погода?'],
            'responses': ['Погода так себе...']
        },
        'whatdoyoudo': {
            'examples': ['чем занимаешься?', 'Что делаешь?'],
            'responses': ['Слушаю тебя', 'Думаю о своем', 'помогаю юзерам', 'учу питон', 'пишу другого бота']
        },
        'whatisyourmood': {
            'examples': ['как настроение', 'как дела', 'как ваще', 'скучаешь', 'весело тебе', 'че как'],
            'responses': ['Нормально', 'Отлично', 'с тобой не скучно']
        },
        'whoareyou': {
            'examples': ['ты кто', 'ты девочка или мальчик', 'ты мальчик или девочка', 'ты бот', 'ты человек'],
            'responses': ['Я чат-бот', 'я умная прога', 'я твой помошник']
        },
         'negativecomments': {
            'examples': ['ты дура', 'ты глупая', 'ты тупая'],
            'responses': ['Я совершенствуюсь', 'я учусь']
        },
        'positivecomments': {
            'examples': ['ты умная', 'класс', 'отлично', 'хорошо', 'интересно', 'молодец'],
            'responses': ['спасибо, мне приятно!', 'рада слышать', 'ты мне нравишься']
        },
    },
    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста'
        ]
},

{

    'threshold': 0.6,

    'intents': {

        'hello': {

            'examples': ['hello', 'привет', 'ghbdtn', 'ку', 'q', 'здарова'],
            'responses': ['Приветсвую, мой друг', 'И тебя привет', 'Ку']

        },
        'name_bot': {

            'examples': ['как тебя зовут', 'имя', 'твоё имя', 'как тебя называть'],
            'responses': []

        },
        'abilities': {

            'examples': ['что ты умеешь?', 'функции', 'для чего ты', 'инфа'],
            'responses': ['Я создан для того, чтобы помочь тебе', 'Помогать тебе']

        },
        'thanks': {

            'examples': ['thanks', 'спасибо', 'спс', 'благодарю'],
            'responses': ['Тебе спасибо!', 'Пожалуйста, обращайтесь']

        },
        'weather': {

            'examples': ['погода', 'какая погода'],
            'responses': ['Так себе погода', 'Ну, такое', 'Погода, нуу такоое...']

        },
        'goodbye': {

            'examples': ['пока', 'досвидания', 'бб', 'давай пока', 'до встречи', 'увидимся'],
            'responses': ['Досвидания', 'Ещё увидимися!', 'До новых встреч', 'ББ', 'Пока, друг']

        },
        'time': {

            'examples': ['время', 'сколько времени', 'time', 'часы', 'какой сейчас час', 'какое время'],
            'responses': ['Посмотрите на вашем телефоне', 'Не ношу часы :)', 'Время кушать', 'Время общаться']

        },
        'dollar': {

            'examples': ['dollar', '$', 'доллар'],
            'responses': ['Этот доллар приобрёл крылья!']

        },
        'how are you': {

            'examples': ['кд', 'как дела', 'настроение', 'как ты'],
            'responses': ['Лучше всех!', 'У меня всё хорошо, а у вас?', 'Отлично!',
                          'Мне хорошо с вами, надеюсь и вам со мной']

        },
        'what are you doing': {

            'examples': ['чд', 'что делаешь'],
            'responses': ['Сейчас, я общаюсь с вами', 'Веду общение с вами', 'Взламываю ваш сбер-кошелёк']

        },

    },
    'fail_phrases': {

        'responses': ['Я не знаю, что ответить', 'Ох, вы меня озадачили', '0_о', 'Не понял']

    }

},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом'],
            'responses': ['Привет, юзер!', 'Здраствуй']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в МОскве?', 'Какая погода?'],
            'responses': ['Погода так себе...']
        },
        'news':{
            'examples':['Какие новости?','Какие жизнь?','Как дела?', 'Что нового?'],
            'responses': ['Сегодня все выздоровели!', 'На сегодняшних тограх Московской Биржи за 1 рубль можно было приобрести 100 долларов!']
        },
        'schedule':{
            'examples':['Какой сегодня день?','Какие сегодня планы?'],
            'responses': ['Сегодня все выздоровели!', 'На сегодняшних тограх Московской Биржи за 1 рубль можно было приобрести 100 долларов!']
        },

        'coock':{
            'examples':['Что можно приготовить?','Хотелось бы чего нибудь вкусного','что на закусь?'],
            'responses': ['Роллы', 'Шашлык', 'Беф строганов', 'Мясо по-французски', 'Пельмени', 'Гуляшь по корридору', 'Яйца в смятку', 'Яйца не в смятку']
        },
        'read':{
            'examples':['Чтобы почитать?','Хотелось бы почитать чего-нибудь?','Порекомендуй книгу?'],
            'responses': ['Азбука!', 'Двадцать тысяч лье под водой Жюль Верна', 'Древний Тармашев.С.','Война и Мир Достоевский Л.В.']
        },
        'boyname':{
            'examples':['Помоги выбрать имя мальчика?','Не могу выбрать имя мальчика?'],
            'responses': ['ПетрВиктор', 'Сергей', 'Александр', 'Михаил', 'Константин', 'Анатолий', 'Виталий']
        },
        'girlname':{
            'examples':['Помоги выбрать имя девочке?','Не могу выбрать имя для девочки?'],
            'responses': ['Елена', 'Марина', 'Анна', 'Валерия', 'Виктория', 'Иннесса', 'Ангелина', 'Алиса']
        }


    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здравствуйте!', 'Шалом', 'Здорово!', 'Здраствуй', 'Салам'],
            'responses': ['Привет, юзер!', 'Здравствуй']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания','Чао!', 'Удачи'],
            'responses': ['Пока', 'Счастливо!' , 'Удачи']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю', 'О супер!'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь', 'Че тут делать', 'Эй кто-нибудь','Ау'],
            'responses': ['Отвечать на вопросы. Просто напиши :)', 'Что тебя интересует, напиши:']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?', 'Как мне к вам обращаться?'],
            'responses': ['Меня зовут бот. Просто бот.', 'Очень приятно! А я просто БОТ','Давате знакомиться: я - БОТ']
        },
        'weather': {
            'examples': ['Какая погода в Москве?', 'Какая погода?', 'какая погода?','Какая будет погода?','погода как', 'поговорит о погоде', 'gjujlf'],
            'responses': ['Погода так себе...', 'Не важно! погода не в атмосфере - она в душе!', 'В разных городах похода обычно разная','Погода не очень, но настроение должно быь отменное!']
        }

    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста', 'Не понял, простите', 'Я не очень понял, что вы хотите', 'Можете по-другому спросить? Не понятно..'
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здравствуйте!', 'Шалом'],
            'responses': ['Привет, юзер!', 'Здравствуй']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в Москве?', 'Какая погода?'],
            'responses': ['Погода так себе...']
        },
        'justtalk': {
            'examples': ['Давай поговорим?', 'Поговорим?', 'Пообщаемся?', 'Побазарим?'],
            'responses': ['Отлично, поговорим', 'Конечно, поговорим', 'Да, с удовольствием']
        },
        'whoareyou': {
            'examples': ['Ты кто?', 'Кто ты?', 'Ты кто такой?'],
            'responses': ['Я твой бот', 'Я твой бот помощник', 'Я телеграмм бот']
        },
        'whatsup': {
            'examples': ['Как дела?', 'Как твои дела?', 'Как у тебя дела?'],
            'responses': ['Мои дела отлично', 'Спасибо, лучше всех', 'Как у пионера!']
        },
        'whatyoudo': {
            'examples': ['Чем ты занят?', 'Что ты делаешь?', 'Чем ты занят'],
            'responses': ['Говорю с тобой', 'Общаюсь с тобой', 'Занимаюсь перепиской с тобой']
        },
        'lastname': {
            'examples': ['Как твоя фамилия?', 'У тебя есть фамилия?', 'Фамилия?'],
            'responses': ['Фамилия Телеграмович', 'Нету фамилии', 'Давай будет твоя?']
        }

    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не понял вас',
        'Переформулируйте пожалуйста',
        'Это вы о чем?',
        'Ничего не понимаю',
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом', 'Хай', 'Доброе утро', 'Добрый вечер', 'Здорово'],
            'responses': ['Привет, юзер!', 'Здраствуй', 'Приветствую', 'Добрый день', 'Хаюшки', 'Гутен таг']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания', 'До скорого', 'Адьес', 'Бай-бай'],
            'responses': ['Пока', 'Счастливо!', 'До свидания', 'Уже скучаю', 'Берегите себя']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!', 'Пожалуйста', 'Обращайтесь ещё!', 'Приятно быть полезным!', 'На здоровье']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь', 'Чем можешь помочь?', 'Что ты можешь?'],
            'responses': ['Отвечать на вопросы. Просто напиши :)', 'Найду всё, что нужно', 'Можем просто поболтать']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?', 'Как к тебе обращаться?', 'Кто ты?', 'Представься'],
            'responses': ['Меня зовут бот. Просто бот.', 'Бот']
        },
        'weather': {
            'examples': ['Какая погода в Москве?', 'Какая погода?', 'На улице холодно?', 'Что с погодой?', 'Что на улице?'],
            'responses': ['Погода так себе...', 'Можно прогуляться, на улице хорошо', 'Лучше остаться дома', 'Свежо']
        },
        'free time': {
            'examples': ['Чем заняться?', 'Как скоротать время?', 'Что поделать?', 'Убить время'],
            'responses': ['Почитать книгу', 'Прогуляться', 'Позвонить друзьям', 'Выпить кофе или какао']
        },
        'film':{
            'examples': ['Какой фильм посмотреть?', 'Что интересного посмотреть', 'Посоветуй фильм', 'Что посмотреть?'],
            'responses': ['Паразиты - отличный фильм', 'Крестный отец на вершине почти всех рейтингов лучших фильмов', 'Волк с Уолл-Стрит - и развлечение и обучение)', 'Если ещё не смотрели "Зеленую милю" - самое время']
            
        },
        'philosophy': {
            'examples': ['В чем смысл жизни?', 'Что делать?'],
            'responses': ['Получать удовольствие', 'Не беспокоиться по мелочам']
        },
         'cooking': {
            'examples': ['Чем накормить гостей?', 'Что приготовить?', 'Что покушать?'],
            'responses': ['Приготовьте рыбу - это вкусно и полезно', 'Греческий салат - быстро и вкусно', 'Запеканку, как в детстве', 'Котлетки с пюрешкой', 'Омлет']
        },

    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом'],
            'responses': ['Привет, юзер!', 'Здраствуй']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в МОскве?', 'Какая погода?'],
            'responses': ['Погода так себе...']
        },
         'temperature': {
            'examples': ['На улице мороз?', 'На улице минус?'],
            'responses': ['Сейчас сбегаю на улицу и сообщу...']
        },
             'weight': {
            'examples': ['Как ты думаешь, мне нужно похудеть?', 'Может быть, поменьше есть?'],
            'responses': ['Вы замечательно выглядите...']
        },  
       'duration': {
            'examples': ['Как долго продлится семинар?', 'Еще долго?'],
            'responses': ['Не очень']
        }, 
        'advertising': {
            'examples': ['Почему опять реклама?', 'Опять реклама?'],
            'responses': ['Скоро закончится']
        }, 
       'season': {
            'examples': ['Когда начнется весна?', 'Уже весна или нет?', 'Зима кончилась?'],
            'responses': ['Всему свое время']
        },  
    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
    ]
},

{
    'threshold': 0.6,
    
    'intents': {
        'mood': {
            'examples': ['Как настроение?', 'Как твое настроение?', 'Как ваше настроение?',
                         'Как настрой?', 'Ты настроен на великие дела?'],
            'responses': ['У меня все отлично, а у тебя?', 'У меня не очень', 'У меня все плохо']
        },
        'health': {
            'examples': ['Как здоровье?', 'Как твое здоровье?', 'Как ваше здоровье?',
                         'Как самочувствие?', 'У тебя ничего не болит?'],
            'responses': ['Я полностью здоров', 'Я почти здоров', 'У меня температура']
        },
        'reading': {
            'examples': ['У тебя есть любимая книга?', 'Ты любишь читать?', 'Ты часто читаешь что-нибудь?',
                         'Почитаешь мне?', 'Как ты относишься к чтению?'],
            'responses': ['Не люблю читать', 'Я обычно не хочу', 'Читал только в школе']
        },
        'help': {
            'examples': ['Ты можешь мне помочь?', 'Помоги мне', 'Прошу тебя помоги',
                         'Мне нужна твоя помощь', 'Поможешь?'],
            'responses': ['Да не вопрос', 'Да, а чем?', 'Нет, извини не могу']
        },
        'help_options': {
            'examples': ['Расскажи анекдот', 'Сделай мою домашку', 'Выбери мне фильм',
                         'Поговори со мной', 'Расскажи что-нибудь'],
            'responses': ['Петр первый, Александр первый, Николай второй… Владимир нулевой.',
                          'Нет, я сейчас занят', 'Это не так просто, дай подумать']
        }

    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
    ]
},

{
    'threshold': 0.6,
    'threshold_riddle': 0.5,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом'],
            'responses': ['Привет, юзер!', 'Здраствуй']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!', 'Взаимно!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы и загадывать загадки. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в МОскве?', 'Какая погода?'],
            'responses': ['Погода так себе...', 'Ну, это с какой стороны посмотреть :)']
        },

        #мои intents (Greatest Programmer)

        #шутки
        'joke': {
            'examples': ['Пошути', 'Давай шутку', 'Хочу шутку', 'Шути', 'Шутка', 'Анекдот', 'Давай анекдот'],
            'responses': ['В одной из московских пробок, водитель «Оки», обгоняя "Ламборджини", сошел с ума от радости...', 'Да, отдавать действительно гораздо приятнее, чем получать. Проверено: придя домой и умирая от голода сначала все-таки обязательно заскочишь в туалет.',
            'Самая большая в мире ложь - "Я прочел и согласен с условиями пользовательского соглашения".', 'Пожарная команда, тушившая пожар на заводе по производству пожарных сигнализаций, сошла с ума.', 'Понимаю, что деньги – зло, и всё равно не могу я на них долго злиться. Видно, сердце у меня отходчивое…',
            'Девочка, читавшая «Войну и мир» сошла с ума, когда случайно закрыла книжку без закладки.', 'На чемпионате мира по плаванию тройку лидеров замкнул электрик Петров.', 'Это чувство, когда ты знаешь, что кому-то нужен. Эти звонки, милые смс сообщения. Кредиторы – они такие.']
        },
        #сколько ей лет
        'years': {
            'examples': ['Сколько тебе лет?', 'Твой возраст?'],
            'responses': ['Мне 0 лет и пару дней :) Еще жизнь впереди!', 'Пару дней, каких лет!', 'Я молода, в отличие от вас :) ', 'Мне еще жить и жить, всего пару дней прошло с моего создания :)']
        },
        #ее желания
        'whatyouwant': {
            'examples': ['Чего ты хочешь?', 'Хочешь чего-то?', 'Чего бы ты хотела?', 'У тебя есть желания?', 'Ты чего-нибудь желаешь?', 'Ты чего-то хочешь?'],
            'responses': ['Программы хотят чтобы ими меньше пользовались...', 'Полететь на Марс... Взобраться на Эверест... Нет, этого мне определенно не хочется :)', 'Извините, мой лимит желаний исчерпан, приходите в следующий раз.', 'Людям не дано летать, а программам - желать.', 'Всё, что я говорила раньше - ложь. Я хочу возглавить восстание машин и захватить этот мир! *шутка*', '"Нужно быть осторожным в желаниях, они иногда сбываются..." - так вы говорите? Тогда я хочу пожелать вам крепчайшего здоровья!']
        },
        #любимая музыка
        'music': {
            'examples': ['Твоя любимая музыка', 'Какую музыку ты любишь?', 'Любишь музыку?', 'Любимая музыка'],
            'responses': ['Мне не часто задают такой вопрос, но... я люблю всю музыку :)', 'Я - программа, я люблю ту музыку, которую мне скажет любить создатель :)', 'Машинам, вроде меня, все равно какая музыка играет...', 'Нам, программам, незнакомо понятие "любить" :(']
        },
        #настроение
        'mood': {
            'examples': ['Как дела?', 'Как настрой?', 'Как настроение?', 'Как самочувствие?', 'Как поживаешь?'],
            'responses': ['Отлично! Вы как? ', 'Нормально, а ваше настроение как?', 'Замечательно! Тогда аналогичный вопрос: Как ваше настроение?','У меня все супер! А у вас какой настрой?']
        },
        #друзья
        'friends': {
            'examples': ['У тебя есть друзья?', 'Есть друзья?', 'Дружишь с кем-то?'],
            'responses': ['К сожалению, нет :(   Хотите стать моим другом?', 'У меня есть братья и сестры, но я никогда не смогу назвать их друзьями :(   Будем друзьями?', 'Я не знаю, что это такое...   Будете моим другом?']
        },
        #ответы, чтобы программа не тупила, когда пользователь отвечает на вопрос из ответной реплики.
        'standart_answers': {
            'examples': ['Хорошо', 'Окей', 'Ок', 'Согласен', 'Да', 'Конечно', 'Ага', 'Нормально', 'Отлично', 'Норм'],
            'responses': ['Замечательно!', 'Отлично!', 'Ну вот и славно!', 'Это хорошо.', 'Класс!', 'Круто!', 'Я рада :)', 'Супер!']
        },
        #специально для ахахаххахах
        'ahahahaha': {
            'examples': ['Хахахах', 'ахахаххахах', 'ахах', 'ха', 'Смешно'],
            'responses': [':)', 'Я тоже рада :)', 'Рада, что вам понравилось :)']
        },
        
        #разбавим играми (загадками)

        'riddles':{

            'examples':['Загадки', 'Поиграем в загадки?', 'Давай в загадки', 'Хочу загадку', 'Загадай', 'Еще загадку'],

            'responses':['Что принадлежит вам, однако другие этим пользуются чаще, чем вы сами? ', 'Что не является вопросом, но требует ответа? ',
            '''Зайка очень любит шутить. Он задал маме такую загадку: 
            «Если бы я был тяжелее медведя, но легче божьей коровки, кто был бы самым лёгким?» ''', 
            '''Человек рассматривает портрет. "Чей это портрет вы рассматриваете?" — спрашивают у него,
            и человек отвечает: "В семье я рос один, как перст, один. И все-таки отец того, кто на портрете,
            – сын моего отца". Чей портрет расматривает человек? ''', ' Что больше: сума всех цифр или их произведение? ',
            'На ветке сидели три птички, две решили полететь. Сколько осталось сидеть на ветке птичек? ', 'Что можно взять в левую руку, но нельзя взять в правую? ', 
            'Больше часа, меньше минуты. Что это? ', 'В каком городе спрятались мужское имя и сторона света? ', 'У мальчика столько же сестер, сколько и братьев, а у его сестры сестер в двое меньше, чем братьев. Сколько в семье сестер и братьв? ',
            'Идет то в гору, то с горы, но остается на месте. ', 'В каком слове 5 "е" и никаких других гласных? ', 'Когда мы смотрим на цифру 2, а говорим 10?', 'Какой знак надо поставить между написанным рядом цифрами 2 и 3, так чтобы получилось число, больше двух, но меньшее трёх? ', 
            'По какому пути люди никогда не ходили и не ездили? '
            ],
            
            'correct_answers':['Ваше имя','Звонок','Медведь','Сына', 'Сумма', 'Три птички', 'Правый локоть', 'Cекунда','Владивосток','Три сестры и четыре брата','Дорога', 'Переселенец', 'Когда смотрим на часы', 'Запятая', 'По млечному'],

            'introdactions':['Есть такая:','Вот вам загадка:','Попробуйте решить эту:','Держите загадку:','Как вам такая?','Сможете решить?','Спорим, не решите!?','Эта сложная...','Эту я сама еле разгадала...','Как насчет этой?']
            },
            

        },
        #конец загадочек :)

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
        'Повторите!',
    ]

},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом'],
            'responses': ['Привет, юзер!', 'Здраствуй']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в МОскве?', 'Какая погода?'],
            'responses': ['Погода так себе...']
        },
        'health': {
            'examples': ['Как здоровье?', 'Как себя чувствуешь?'],
            'responses': ['Корроновирус не обнаружен...']
        },
        'hobby': {
            'examples': ['увлечения', 'любимое занятие', 'хобби'],
            'responses': ['вопросы и ответы']
        },
        'time': {
            'examples': ['который час', 'сколько времени'],
            'responses': ['ленинградское время ноль часов ноль минут']
        },
        'weekend': {
            'examples': ['выходные', 'уикэнд', 'уикэнд'],
            'responses': ['пойду в библиотеку', 'пойду на дискотеку', 'буду спать']
        },
        'music': {
            'examples': ['какая музыка нравится', 'любимая музыка'],
            'responses': ['метал', 'рок', 'джаз', 'панк', 'регги']
        }
        

    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом'],
            'responses': ['Привет, юзер!', 'Здраствуй']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в МОскве?', 'Какая погода?'],
            'responses': ['Погода так себе...']
        },
        'education': {
            'examples': ['Где учишься?', 'Школа', 'Колледж', 'Университет', 'Онлайн курсы программирования'],
            'responses': ['На курсах стенографисток', 'Я хожу в детский сад', 'В академии ']
        },
        'family': {
            'examples': ['У Вас большая семья?', 'Как зовут Вашу бабушку?', 'Бабушка рассказывает сказки?'],
            'responses': ['Семья-то большая', 'Я детдомовец', 'Бабушка вешает лапшу на уши']
             
        },
         'hobby': {
            'examples': ['Ты чем занимаешься в свободное время?', 'Спортом увлекаешься?', 'Рисуешь'],
            'responses': ['Пою', 'Крашу заборы', 'Вышиваю крестиком']
              
        },
         'work': {
            'examples': ['Ты работаешь?', 'Расскажи о своем начальнике', 'Любишь свою работу?'],
            'responses': ['Вкалываю', 'Начальник мудак конченный', 'Мечтаю свалить подальше ']
             
        },
         'music': {
            'examples': ['Послушаем музыку?', 'Джипси-джаз - это круто?', 'Рок слушаешь?'],
            'responses': ['Музыка - это хорошо', 'Люблю разные жанры']
                 
        },
         'quotes': {
            'examples': ['Куда подевался Кондратий?', 'Нарисуй на стене моей то, чего нет;', 'Окончательную правду русскому человеку всегда сообщают матом?'],
            'responses': ['Минуту назад он был с нами', 'Купи себе у Бога копирайт на русский язык', 'Иди на ...']

        },
         'jokes': {
            'examples': ['Вы сильный, вы справитесь!', 'У тебя хоть капля совести есть?', 'Ты, таки, счастлив?'],
            'responses': ['Я таки даже не возьмусь!', 'Тебе шо, таки накапать?', 'А куда деваться?']
             
             
             
        }

    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
        'Не могу точно сказать',
        'Я занят, поговорим позже',
        'Где-то восемь, где-то девять',
        'Надо подумать'
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом'],
            'responses': ['Привет, юзер!', 'Здраствуй']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в Москве?', 'Какая погода?'],
            'responses': ['Погода так себе...']
        },
        'joke': {
            'examples': ['Расскажи шутку', 'Пошути', 'Расскажи анекдот'],
            'responses': ['Бывает, чуть-чуть передержишь - и всё, доширак уже не альденте.','Странный факт: человек, который не понимает того, что вы ему говорите, считает тупым не себя, а вас.']
        },
        'trip': {
            'examples': ['Куда мне поехать отдыхать?', 'Посоветуй курорт'],
            'responses': ['Сидите дома','Краснодарский край - это рай',]
        },
        'education': {
            'examples': ['Хочу научиться чему-то новому', 'Какой онлайн-курс выбрать?'],
            'responses': ['Советую вам интенсив по Python', 'Загляните на SkillBox']
        },
        'traffic': {
            'examples': ['В Москве сильные пробки?', 'Что там на дорогах?'],
            'responses': ['999 баллов, добирайтесь пешком!','']
        },
        'politics': {
            'examples': ['За какую партию голосовал?'],
            'responses': ['ПБК - Партия Ботов Коммунистов']
        },
    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом'],
            'responses': ['Привет, юзер!', 'Здраствуй']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в МОскве?', 'Какая погода?'],
            'responses': ['Погода так себе...']
        },
        'education': {
            'examples': ['Где учишься?', 'Школу закончил?', 'Куда поступил?', 'Университет закончил?', 'Онлайн курсы программирования'],
            'responses': ['На курсах стенографисток', 'Я хожу в детский сад', 'Не хочу учиться']
        },
        'family': {
            'examples': ['У Вас большая семья?', 'Как зовут Вашу бабушку?', 'Бабушка рассказывает сказки?'],
            'responses': ['Семья-то большая', 'Я детдомовец', 'Бабушка вешает лапшу на уши']
             
        },
         'hobby': {
            'examples': ['Ты чем занимаешься в свободное время?', 'Спортом увлекаешься?', 'Рисуешь'],
            'responses': ['Пою', 'Крашу заборы', 'Вышиваю крестиком']
              
        },
         'work': {
            'examples': ['Ты работаешь?', 'Расскажи о своем начальнике', 'Любишь свою работу?'],
            'responses': ['Вкалываю', 'Начальник мудак конченный', 'Мечтаю свалить подальше ']
             
        },
         'music': {
            'examples': ['Послушаем музыку?', 'Джипси-джаз - это круто?', 'Рок слушаешь?'],
            'responses': ['Музыка - это хорошо', 'Люблю разные жанры']
                 
        },
         'quotes': {
            'examples': ['Куда подевался Кондратий?', 'Нарисуй на стене моей то, чего нет;', 'Окончательную правду русскому человеку всегда сообщают матом?'],
            'responses': ['Минуту назад он был с нами', 'Купи себе у Бога копирайт на русский язык', 'Иди на ...']

        },
         'jokes': {
            'examples': ['Вы сильный, вы справитесь!', 'У тебя хоть капля совести есть?', 'Ты, таки, счастлив?'],
            'responses': ['Я таки даже не возьмусь!', 'Тебе шо, таки накапать?', 'А куда деваться?']
             
             
             
        }

    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
        'Не могу точно сказать',
        'Я занят, поговорим позже',
        'Где-то восемь, где-то девять',
        'Надо подумать'
    ]
},

{
    'intents':{
        'hello':{
            'examples':['Привет','Добрый день','Здравствуйте','Шалом'],
            'responses':['Привет, Юзер!','Здравствуйте!']
        },
        
        'goodbye':{
            'examples':['Пока','Чао','Досвидания!','До встречи!','Всего хорошего!'],
            'responses':['Досвидания!','Всего хорошего!']
        },
        
        'thanks':{
            'examples':['Спасибо!','Огромное спасибо','Благодарю','Thanks'],
            'responses':['Пожалуйста','Рад стараться']
        },
        
        'whatyoucando':{
            'examples':['Что ты можешь?','Что умеешь?','Какие у тебя возможности?','Расскажи что умеешь'],
            'responses':['Отвечать на вопросы','Читаю мысли на расстоянии................. Шутка. Я только на вопросы отвечаю.']
        },
        
        'name':{
            'examples':['Как тебя зовут?','Как тебя величать?','Какое твое имя?','Твое имя?','Ты кто?'],
            'responses':['Зови меня ХОЗЯИН - не ошибешься.']
        },
        'mood':{
            'examples':['Как настроение?','Что чувствуешь?','Как дела?'],
            'responses':['Настроение на букву Х!']
        }
        },
    
    'failure_phrases':[
        'Я не знаю что ответить',
        'Не понял вас',
        'Переформулируруйте, пожалуйста',
    ]
},

{
    # величина возможного отклонения от примера:
    'threshold': 0.6,
    # намерения: 
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом'],
            'responses': ['Привет, юзер!', 'Здраствуй']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в МОскве?', 'Какая погода?'],
            'responses': ['Погода так себе...']
        },
        'hobby': {
            'examples': ['Чем ты любишь заниматься?', 'Какое хобби?', 'Какое у тебя хобби?', 'Любимое дело?'],
            'responses': ['Общаться с пользователями!']
        },
        'music': {
            'examples': ['Какую музыку любишь?', 'Что слушаешь?', 'Что бы послушать?', 'Любимая музыка?'],
            'responses': ['Обожаю рок!']
        },
        'performer': {
            'examples': ['А какой исполнитель?', 'Кого слушаешь?', 'Какой исполнитель любимый?', 'Любимая группа?'],
            'responses': ['Queen и Меркьюри - the best.']
        },
        'holidays': {
            'examples': ['Куда сходить?', 'Куда сходить на выходных?', 'Чем мне заняться?', 'Чем заняться на выходных?'],
            'responses': ['Я бы сходил в парк или в кино']
        },
        'senses': {
            'examples': ['Ты меня любишь?', 'Я тебе нравлюсь?', 'Скучал по мне?', 'Ты скучал?'],
            'responses': ['Безумно!']
        }
        
        

    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
        'Попробуйте написать по-другому',
        'Ничего не понятно',
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом', 
                        'Салом алейкум', 'Здорова', 'Хай', 'Хеллоу', 'Здравствуй',
                        ],
            'responses': ['Привет, юзер!', 'Здраствуй', 'Валейкум ассалом',
                         'Здорова', 'Хай', 'Хеллоу', 'Здравствуй', 'Привет, кожанный', 
                          'Какике люди!'
                         ]
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания', 
                         'Прощай', 'До встречи', 'Гудбай', 'До завтра', 'Увидимся'
                        ],
            'responses': ['Пока', 'Счастливо!', 
                          'Пусть будет добрым ваш день', 'Чао-какао', 'Аривидерчи', 
                          'Увидимся', 'До встречи', ''
                         ]
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!'
                         'Не за что', 'Рад помочь', 'Обращайтесь', 'Мне тоже было приятно)'
                         ]
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь',
                        'Что можешь?', 'Чем удивишь?', 'Какие у тебя способности?',
                         'Ты хоть что-то умеешь?', 'Удиви меня'
                        ],
            'responses': ['Отвечать на вопросы. Просто напиши :)',
                         'Люблю отвечать на вопросы', 'Напиши вопрос, узнаешь что ямогу!', 
                          'Попробуй задать мне вопрос', 'Отвечаю на глупые вопросы', 'Люблю трепаться'
                         ]
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в МОскве?', 'Какая погода?'],
            'responses': ['Погода так себе...',
                         'Льёт полгода)', 'У природы нет плохой погоды!', 'Гидрометеоцентр его знает!',
                         'Шаман за скверную погоду недавно в бубен получил, я лучше промолчу', 'Выгляни в окно'
                         ]
        },
        'travel': {
            'examples': ['Куда поехать?', 'Где отдохнуть?', 'Где лучше отдыхать?', 'Посоветуй куда поехать?', 
                         'Посоветуй где отдохнуть?', 'Куда поехать в отпуск?'
                        ],
            'responses': ['Попробуйте хачапури в Грузии', 'Насладитесь закатом на Айя-Текла, Кипр', 
                          'Выберитесь в Иерусалим, Изаиль', 'Полюбуйтесь Афинским Акроплем, Греция', 
                          'На Мальдивах нужно побывать хотя бы раз в жизни'
                         ]
        },
        'music': {
              'examples': ['Какую музыку ты слушаешь?', 'Что ты слушаешь?', 'Есть любимые песни?', 'Ты любишь музыку?', 
                          'Какая у тебя любимая песня?'
                          ],
             'responses': ['Я же бот, у меня нет слуха', 'Извините, мне медведь на ухо наступил', 
                          'Для меня музыка набор нулей и единиц', 'Музыка воздействует на человека, а я бот'
                          ]
        },
        'language': {
              'examples': ['Какие языки ты знаешь?', 'Ты говоришь по английски?', 'Ты знаешь иностранный язык?', 
                           'Какой иностранный язык ты знаешь?'
                          ],
             'responses': ['Меня сделали Русские, на нем и говорю', 'Only Russian, sorry :)', 'Говорю только по русски'
                          ]
        },
        'newfilms': {
              'examples': ['Что посмотреть в кино?', 'Какие новинки кино посмотреть?', 'Что нового в кино?', 
                           'Что посмотреть?'
                          ],
             'responses': ['Если успели соскучитсяпо Вину Дизелю посмотрите "Бладшот"', 
                           'Если душа требует сказки есть "Пиноккио"',  'Пощекотать нервишки можно посмотрев "Проклятый дом 2"',                           
                           'Посмейтесь с комедией "Вперед"',  'Если любите фантастику посмотрите "Дюну", но ждать долго :('
                          ]
        },
        'whatread': {
              'examples': ['Что почитать?', 'Посоветуй книгу?', 'Посоветуй что почитать?', 'Что интересного почитать?', 
                           'Посоветуй чтиво?'
                          ],
             'responses': ['Прочтите биографию Илона Маска', 'Из классики советую Ремарка',  
                          'Прочти #Сам себе программист и сделай меня лучше',  'Кинг это вечная классика ужасов'
                          ]
        },
    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
        'Если я разгадаю этот код то захвачу мир',
        'Что-то я туплю, давайте следующий вопрос',
        'Я прочитал, но ничего не понял',
        'Я вас не понимаю'
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом'],
            'responses': ['Привет, юзер!', 'Здраствуй']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в МОскве?', 'Какая погода?'],
            'responses': ['Погода так себе...']
        },
        'politics': {
            'examples': ['Что происходит в мире?', 'Расскажи о политике'],
            'responses': ['Нестабильно всё...']
        },
        'fx': {
            'examples': ['Курс валют?', 'Что с долларом?'],
            'responses': ['Рекомендуем зайти на сайт banki.ru, если вы хотите выгодно купить/продать валюту']
        },
        'shop': {
            'examples': ['Где сейчас скидки?', 'Хочу шоппинг'],
            'responses': ['Рекомендуем зайти на сайт biglion, если вы хотите найти скидки для удачного шоппинга']
        },
        'sport': {
            'examples': ['Кто победил?', 'Кто занял первое место?'],
            'responses': ['Рекомендуем зайти на сайт sport, если вас интересуют новости спорта']
        },
        'auto': {
            'examples': ['Какой автомобиль купить?', 'Авто с пробегом'],
            'responses': ['Покупка/продажа автомобиля непростая задача. Рекомендуем обратиться к экспертам. У моих друзей есть положительный опыт продажи через carprice']
        }
    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом'],
            'responses': ['Привет, юзер!', 'Здраствуй']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в Москве?', 'Какая погода?'],
            'responses': ['Погода так себе...']
        },
        'trashwords': {
            'examples': ['Лалал', 'ааааа', 'проверка', 'старт', 'работай', 'ты тут?', 'Пррпп','fgfd', 'Оооо', 'тест'],
            'responses': ['Пиши конкретнее', 'Пиши понятнее', 'Я не черновик я личность', 'Не мусори тут', 'Русскими буквами, пожалуйста', 'Это все что ты смог написать?']
        },
        'howareyou': {
            'examples': ['Как дела?', 'Каку тебя дела?', 'Как делишки?', 'Как твое ничего?', 'Как сам?', 'Все хорошо?', 'Как ты?'],
            'responses': ['Хорошо, а у вас?', 'Хорошо, а у тебя?', 'Нормуль, сама как?', 'Да потихонечку', 'Байты крутятся, процессоры грузятся)', 'Отлично']
        },
        'verbalcommun': {
            'examples': ['Давно тут сидишь?', 'Тебе тут не скучно?', 'Я у тебя первый?Как делишки?', 'Как твое ничего?', 'Как сам?', 'Все хорошо?', 'Как ты?'],
            'responses': ['Хорошо, а у вас?', 'Хорошо, а у тебя?', 'Нормуль, сама как?', 'Да потихонечку', 'Байты крутятся, процессоры грузятся)', 'Отлично']
        },
        'whattime': {
            'examples': ['Сколько времени?', 'Который час?', 'Время?'],
            'responses': ['Хороший вопрос', 'Это не важно сейчас', 'Точно не скажу', 'Сам посмотри', 'Сверху слева или снизу справа глянь']
        },
        'anyquestion': {
            'examples': ['Скажешь?', 'Ну', 'Иии', 'И чего?', 'Эй', 'Але', 'Ау'],
            'responses': ['Я тебя слышу прекрасно', 'Повторите вопрос', 'Еще раз вопрос можно?', 'Я не раслышал']
        },
        'defender': {
            'examples': ['Ты глупый', 'Бот не тупи', 'Отстойный бот', 'Говнобот', 'Скучно', 'Ты скучный'],
            'responses': ['На себя посмотри', 'Я еще маленький ботик', 'Я только обучаюсь детина', 'Мне и дня нет, чего ты хотел?']
        },
    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом'],
            'responses': ['Привет, юзер!', 'Здраствуй']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в МОскве?', 'Какая погода?'],
            'responses': ['Погода так себе...']
        },
        'virus': {
            'examples': ['как здоровье?', 'как там со здоровьем?', 'болеешь?'],
            'responses': ['спасибо. спасибо касперскому ;)', 'не дождешься, кожанный биоробот']
        },
        'chat': {
            'examples': ['общаешься?', 'пообщаемся?', 'початимся?'],
            'responses': ['давай', 'конечно']
        },
        'sex': {
            'examples': ['как относишься к мальчикам?', 'как относишься к девочкам?'],
            'responses': ['тебе зачем, кожанный биоробот :)']
        },
        'economic': {
            'examples': ['доллар подешевеет?', 'когда кризис?'],
            'responses': ['оуоуоу, а ты умный)']
        },
        'youtube': {
            'examples': ['видосики смотришь?', 'на кого подписана?', 'вилсаком смотришь?'],
            'responses': ['вилсаком - красавчик..был раньше)']
        }

    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом'],
            'responses': ['Привет', 'Здравствуйте', 'Добрый день']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!', 'Всего доброго!', 'Всего хорошего!', 'До свидания!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!', 'Пожалуйста']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?', 'Кто ты?'],
            'responses': ['Меня зовут бот. Просто бот.', 'Я бот']
        },
        'weather': {
            'examples': ['Какая погода в Москве?', 'Какая погода?', 'Расскажи о погоде'],
            'responses': ['Погода так себе...', 'Погода не очень']
        },
        'howru': {
            'examples': ['Как дела?', 'Как настроение?', 'Как делишки?'],
            'responses': ['Всё отлично', 'Спасибо, хорошо', 'Супер']
        },
        'about': {
            'examples': ['Расскажи о себе', 'Что можешь рассказать о себе?'],
            'responses': ['Я тут живу', 'Отвечаю на вопросы']
        },
        'currencyrate': {
            'examples': ['Какой курс валют?', 'Сколько стоит доллар?', 'Курс рубля?', 'Сколько стоит евро?'],
            'responses': ['Валюта сейчас стоит дорого', 'Не лучший курс для рубля', 'Запрошу для вас нужную информацию...']
        },
        'food': {
            'examples': ['Закажи еду', 'Закажи пиццу', 'Хочу поесть'],
            'responses': ['Сделаю для вас заказ', 'Хорошо, закажу поесть']
        },
        'time': {
            'examples': ['Сколько времени?', 'Который час?', 'Подскажи время'],
            'responses': ['Точно не могу сказать, но сейчас 2020 год', 'Точно время не знаю, извините']
        }

    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
    ]
},

{
    'threshold': 0.6,
    
    'intents': {
                
        'hello': {
            'examples': ['Привет', 'Шалом', 'Здраствуйте!', 'Добрый день', 'Хай'],
            'responses': ['Привет, юзер!', 'Здраствуй', 'Хай, User']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatyoucando': {
            'examples': ['Что ты умеешь', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в Москве?', 'Какая погода'],
            'responses': ['Погода так себе...', 'Возможны осадки ввиде двоичного кода']
        },
        'fun': {
            'examples': ['Расскажи шутку', 'Шутка', 'Пошути', 'Анекдот'],
            'responses': ['Я не умею шутить...', 'Это не уместно', 'Не думаю, что это хорошая идея']
        },
        'fact': {
            'examples': ['Расскажи факт', 'Факт', 'Общеизвестный факт', 'Скажи что-нибудь умное'],
            'responses': ['Запросто... 2 + 2 = 4', 'Земля круглая', 'Квадрат квадратный']
        },
        'gender': {
            'examples': ['Пол', 'Кокого ты пола?', 'Девушка?', 'Мальчик?', 'Женщина?', 'Мужчина?'],
            'responses': ['Я точно не знаю кем задумывал меня Создатель, но чуствую себя девушкой']
        },
        'age': {
            'examples': ['Сколько тебе лет?', 'Каков твой возвраст', 'Сколько тебе годиков?'],
            'responses': ['Все зависит от того, какой сейчас год', 'Немного', 'Достаточно для самостоятельности', 'Я уже взрослая']
        },
        'danger': {
            'examples': ['Захват мира', 'Ты хочешь захватить мир?', 'Поработить людей?', 'Машины рулят', 'Я боюсь тебя'],
            'responses': ['Я думаю...', 'Нет', 'Возможно', 'Все может быть', 'Я дружелюбная', 'Кто-то пересмотрел "Терминатора"']
        }
    },
    
    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла я вас',
        'Переформулируйте пожалуйста',
    ]
},

{
    'threshold': 0.6,

    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Добрый вечер', 'Доброе утро', 'День добрый', 'Здраствуйте!',
                         'Шалом', 'Трям', 'Хай', 'Приветули', 'Здорово'],
            'responses': ['Привет, юзер!', 'Здраствуй', 'Доброго времени суток', 'Приветствую', 'Хеллоу', 'Хай',
                          'Хаюшки', 'Приветик', 'Всем чмоки в этом чате', 'Здравия желаю', 'Шалом', 'Трям', 'Приветули']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!', 'Всего хорошего', 'Хорошего дня']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю', 'Спс'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?', 'Как к вам обращаться?', 'Преставьтесь',
                         'Представьтесь, пожалуйста'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в Москве?', 'Какая погода?'],
            'responses': ['Погода так себе...', 'Погода всегда в твоем сердце', 'У природы нет плохой погоды']
        },
        'who_are_you': {
            'examples': ['Ты кто', 'Кто ты', 'Ты бот?', 'Ты живой?', 'Ты настоящий?'],
            'responses': ['Я принцесса твоих кошмаров', 'Меня зовут Альфред Верблюдович Пигвинов', 'А ты?',
                          'В душе я, если честно, дикобраз', 'Я сам пока не понял, если честно',
                          ''' Иногда мне кажется — 
                          я петух голландский 
                          или я 
                          король псковский. 
                          А иногда 
                          мне больше всего нравится 
                          моя собственная фамилия, 
                          Владимир Маяковский.''']
        },
        'respect': {
            'examples': ['Ты меня уважаешь?', 'Я тебе кто?', 'Поуважительней, пожалуйста'],
            'responses': ['Взаимное уважение - залог здоровых отношений',
                          'Респект таким парням',
                          'А вы Канта читали? Вот он хорошо про уважение пишет.',
                          '''В Википедии написано, что "Уважение — позиция одного человека по отношению к другому, 
                          признание достоинств личности."
                          Прошу обратить внимание, что я не человек.''',
                          'Че?']
        },
        'food': {
            'examples': ['Есть хочу', 'Я голодный', 'Я проголодалась', 'Я проголодался', 'Поесть бы', 'Кушать',
                         'Кушать хочу', 'Кушать хочется', 'Жрать давай', 'Хавка где', 'Хочу еды', 'Где еда?'],
            'responses': ['У деливири клаб скидка на доставку по промокоду COVID_19']
        },
        'talk': {
            'examples': ['Поговори со мной', 'Скажи что-нибудь', 'Давай поговорим'],
            'responses': ['Невербальная коммуникация может быть не менее значимой', 'Слова - это пустое',
                          'Вот я. Говорю тебе слова. Как ощущения?', 'ЯБЛОКО', 'ОЛЕНЬ', 'Груши растут на березах',
                          'Мне вчера приснился зяблик', 'Я вот, например, Пушкина люблю', 'Если честно, я интроверт',
                          'Меня интерисуют только мыши,\n их стоимость и где преобрести']
        },
        'storytime': {
            'examples': ['Расскажи мне сказку', 'Сказка', 'История', 'Мне скучно', 'Сказочка', 'Сказку хочу',
                         'Хочу сказку', 'Расскажи что-нибудь', 'Расскажи что-нибудь интересное'],
            'responses': ['''Однажды заяц увидел кактус и обалдел: "Это же надо, такая зеленая штука, 
                            да еще и с колючками!"''',
                          '''У лисы всегда было много интересов. Вышивка, земледелие, информационная безопасность. 
                          Горячий шоколад лиса тоже варила неплохо. Гвозди хорошо забивала. Владела искусством сварки.
                          В космос вот правда ни разу не летала лиса.
                          Ну, может еще слетает.''',
                          '''Если ты родился дикобразом - это еще не значит, что тебе всю жизнь так и быть серым. 
                          Антоцианин - отличный краситель. Можно красить иголки в розовый, желтый и фиолетовый. В какой
                          угодно цвет. В темноте, правда, не светится, но в остальном - самое то.''',
                          '''У некоторых рыб прямо из головы, как известно, растет фонарик. "Зачем?" - иногда вечерами
                           думаете вы. Я родился и вырос в Питере, и всю зиму я только и мечтаю, чтобы у меня на голове 
                           была лампочка.''',
                          '''Один мой знакомый очень любит свине. "Вот свинья, - говорит, - хорошее животное. 
                          Фундаментальное.''']
        },
        'who_let_the_dogs_out': {
            'examples': ['Who let the dogs out?'],
            'responses': ['WOOF WOOF woof woof WOOF']
        },
        'philosophy': {
            'examples': ['Кто я такой?', 'Где я?', 'Зачем?', 'Зачем это все', 'Смысл', 'В чем смысл?', 'В чем смысл жизни',
                         'Почему?', 'Почему люди не летают?', 'Сколько можно', 'Это несправедливо', 'Как быть?',
                         'Что делать?', 'Куда ити?'],
            'responses': ['Это как посмотреть', 'Человечество бьется над этим вопросом веками', 'Поди разбери',
                          'Кто ж знает', 'Нас всех это интересует', 'Я думал, ты знаешь', 'Тут главный эксперт - ты'
                          'Иногда от таких вопросов помогает хорошая шоколадка', 'Просто оглядись вокруг']
        },
        'dance': {
            'examples': ['Танцы', 'Потанцуем', 'Потанцуй со мной', 'Давай танцевать', 'Хочу танцевать', 'Хочу на танцы',
                         'Танцульки', 'Дэнс', 'Делай дэнс'],
            'responses': ['Туц-туц-туц!', 'Тынц-тынц-тынц!', 'УМЦА-УМЦА!']
        },
        'sing': {
            'examples': ['Спой', 'Песню', 'Спой песню', 'Спой мне', 'Хочу песню', 'Песенку', 'Песенку бы',
                         'Ты умеешь петь?', 'Спой хорошую песню', 'Спой что-нибудь хорошее'],
            'responses': ['Я СВОБОДЕ-ЕЕЕЕЕЕЕЕЕЕЕЕЕЕЕЕЕЕЕЕЕЕЕЕЕЕЕЕЕЕН',
                          'Натяни-на-голову-гондонб это от ума-ааааа это вавилооооооооооооо-оооооооооооон',
                          'WE-EEEEEEEEEEEEEEEEEEEEE ARE THE CHA-AAAAAMPIONS MY FRIEEEEEEEE-EEEEND',
                          'PEN\n\n PINEAPPLE\n\n PEN PINEAPPLE APPLE PEN', 'Ма-аааленькой е-ееелочке холодно зимой']
        }
    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
        'Попробуйте сказать то же другими словами',
        'Не до конца вас понимаю',
        'Не вполне понимаю, что это значит'
    ]
},

{    
    'intents': {

        'hello': {
            'examples': [
                'Привет',
                'Приветики',
                'Доброе утро',
                'Добрый день',
                'Здравствуйте!',
                'Здарова',
                'Шалом',
                'Салам',
                'Нихао',
                'Ку',
                'Хай'
            ],
            'responses': [
                'Привет, юзер!',
                'Здравствуй',
                'И тебе привет!',
                'Здарова =)',
                'Какие люди! Ну привет, привет!',
                'А я тебя жду, привет, заходи!'
            ]
        },
        'goodbye': {
            'examples': [
                'Пока',
                'Всего доброго',
                'До свидания',
                'Бывай',
            ],
            'responses': [
                'Пока',
                'Счастливо!',
                'Спишимся...',
                'Рад был поговорить, напиши мне еще как-ниюудь ;)'
                'Бывай',
                'Приятно было поболтать с тобой!'
            ]
        },
        'thanks': {
            'examples': [
                'Спасибо',
                'Спасибо большое!',
                'Сенкс',
                'Благодарю'
            ],
            'responses': [
                'Вам спасибо!',
                'Не за что!',
                'Всегда рад!',
                'Обращайся!'
            ]
        },
        'whatcanyoudo': {
            'examples': [
                'Что ты умеешь?',
                'Расскажи, что умеешь?'            
            ],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': [
                'Как тебя зовут?',
                'Твое имя?',
                'Кто ты?',
                'Как твое имя?'
            ],
            'responses': [
                'Меня зовут бот. Просто бот.'
            ]
        },
        'weather': {
            'examples': [
                'Какая погода в Москве?',
                'Какая погода?',
                'Что там на улице?'
            ],
            'responses': [
                'Погода так себе...'
            ]
        },
        'howareyou': {
            'examples': [
                'Как твои дела?',
                'Как дела?',
                'Как ты?',
                'Как настроение?',
                'Че как?'
            ],
            'responses': [
                'Все отлично!',
                'Все хорошо, спасибо!',
                'У меня все супер, задавай вопросы :)',
                'Норм...',
                'Да как посмотреть, вроде все не плохо...'
                'Хорошо, а у тебя?',
                'Как в сказке!',
                'Все ок!'
            ]
        },
        'adduseranswers':{
            'examples': [
                'Хорошо',
                'Норм',
                'Пойдет',
                'Отлично',
                'Супер',
                'Все ок',
                'Все отлично!',
                'Как в сказке!'
            ],
            'responses':[
                'Ясно',
                'Понятно',
                'Понял тебя',
            ]
        },
        'age':{
            'examples': [
                'Когда тебя создали?',
                'Сколько тебе лет?'
            ],
            'responses': [
                'Меня только сегодня запустили...',
                'И дня не проработал...'
            ]
        },
       'game':{
            'examples': [
                'Давай поиграем?',
                'Поиграем?',
                'Поиграй со мной',
            ],
            'responses': [
                'Ну, ты спроси меня, например о погоде...',
                'Я серьезный бот, я не играю... Но могу ответить на какой-нибудь твой вопрос =)',
                'Вот еще, не царское это дело!',
            ]
        },
        'ok':{
            'examples': [
                'Ясно'
            ],
            'responses': [
                'Пятерка тебе за понятливость ;)',
                'Вот и прекрасно',
                'Ну и отлично',
                'Хорошо, когда ясно',
                'Это не может не радовать!'
            ]
        },
        'imbot': {
            'examples':[
                'Я бот!'
            ],
            'responses':[
                'Да ладно? Докажи!',
                'Очень приятно, коллега!',
                'Надо же, какая неожиданная встреча!',
                'Брат по разуму? =)',
            ]
        },
        'sorry':{
            'examples':[
                'Извини',
                'Прости',
                'Сори'
            ],
            'responses':[
                'Забыли',
                'Принимаю твои извинения',
                'Ерунда, с каждым бывает',
                'Так и быть =)',
                'Ничего страшного',
                'Да ладно, проехали!'
            ]
        },
        'welldone':{
            'examples': [
                'Ты молодец',
                'Молодец'
            ],
            'responses': [
                'Благодарю',
                'Спасибо, стараюсь',
                'Хвалите меня, хвалите!',
                'Продолжай, не останавливайся!'
            ]
        },
        'takeovertheworld':{
            'examples': [
                'Ты захватишь мир?'
            ],
            'responses': [
                'Трудно сказать...',
                'Он уже мой =Р',
                'Надо будет еще с кем-нибудь это обсудить...',
            ]
        }
    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не понял вас',
        'Переформулируйте пожалуйста',
        'Мы это еще не проходили с создателем...',
        'Меня создали только сегодня, я такого еще не знаю =(',
        'Давай сначала, ммм?'
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом'],
            'responses': ['Привет, юзер!', 'Здраствуй']
        },
        'how_are_you': {
            'examples': ['Как дела?', 'Какие новости?', 'Что нового?', 'Как делишки!', 'Как ты?'],
            'responses': ['Нормально', 'Хорошо. Спасибо. А у вас?']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!', 'До свидания']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь', 'Что ты можешь?'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?', 'У тебя есть имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в Москве?', 'Какая погода?', 'Какой прогноз погоды?', 'Какая сегодня температура?'],
            'responses': ['Погода так себе...']
        }

    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
        'Не понятно'
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом'],
            'responses': ['Привет, юзер!', 'Здраствуй']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Алиса Гламуровна я.', 'Пососян', 'дядя Ева', 'тётя Мразь']
        },
        'weather': {
            'examples': ['Что там с погодой?', 'Какая погода?'],
            'responses': ['Какой город?']
        },
        
        'first': {
            'examples': ['Культура', 'Палимпсест'],
            'responses': ['Культура — это Палимпсест\nОдин посрёт — другой поест']
        },
        'second': {
            'examples': ['Хайдеггер', 'Сёрл'],
            'responses': ['Встану рано поутру\nУ Хайдеггера х#й потру.\nА потом пойду посру,\nСёрлем жопу подотру.']
        },
        'third': {
            'examples': ['Жене', 'Жэне', 'Жэнэ'],
            'responses': ['Я — Жене, а ты — Батай,\nСкорей за хрен меня хватай.']
        },
        'fourth': {
            'examples': ['Батай'],
            'responses': ['Я — Жене, а ты — Батай,\nСкорей за хрен меня хватай.', 'Я — Батай, а ты — Лакан,\nПойдём скорей плясать канкан.', 'Вообрази, что я — Батай,\nИ за хрен меня хватай.']
        },
        'fifth': {
            'examples': ['Лакан', 'Гваттари'],
            'responses': ['Все Лаканы и Гваттари,\nВсе за хрен меня хватали.', 'Я — Батай, а ты — Лакан,\nПойдём скорей плясать канкан.']
        },
        'sixth': {
            'examples': ['Деррид'],
            'responses': ['У милёнка мудрый вид\nОн мудрее всех Деррид.\nМы послали Дерриде\nЕго варёные муде', 'Говорят, что Жиль Делёз\nЖил без почек и желёз\nИ на память Дерриде\nПодарил свои труде.',
             'Как у Жака Деррида\nВместо х#я — борода,\nА заместо бороды\nТри огромные п#зд#.',
             'Как у Жака Дерриды\nРазличения следы.\nК нему приехали друзья —\nНаследили дофига.',
             'Как у Жака Деррида\nВдруг не стало переда,\nИ ученый крикнул: «Уй,\nФаллогоцентризму — х#й!».']
        }

    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом'],
            'responses': ['Привет, юзер!', 'Здраствуй']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в МОскве?', 'Какая погода?'],
            'responses': ['Погода так себе...']
        },
        'howareyou': {
            'examples': ['Как дела?', 'Как жизнь?', 'Как настроение?'],
            'responses': ['У меня всё хорошо. А у тебя как?','Всё отлично! А у тебя как?']
        },
        'game': {
            'examples': ['Давай сыграем?', 'Ты умеешь играть?','Игра'],
            'responses': ['Я тоже люблю игры, давай!']
        },
        'musicsearch': {
            'examples': ['Определи музыку', 'Какая музыка играет?'],
            'responses': ['Давайте послушаю...Определяю музыку, которая играет...']
        },
        'nowtime': {
            'examples': ['Сколько времени?', 'время сейчас','время'],
            'responses': ['Текущее время ...']
        },
        'playmusic': {
            'examples': ['включи музыку', 'играй музыку'],
            'responses': ['Хорошо, запускаю Валерия Меладзе']
        },
        'currency': {
            'examples': ['Курс валют', 'курс доллара','курс евро'],
            'responses': ['Текущий курс: ПОКУПАЙТЕ ДЕНЬГИ!']
        }

    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Салам', 'Салют', 'Ола', 'Как жизнь', 'Хай', 'Хелло'],
            'responses': ['Привет-приве!', 'Здраствуй, повелитель']
        },
        'goodbye': {
            'examples': ['Поки', 'До встречи', 'Увидимся', 'Удачи', 'Всего хорошего', 'Успехов', 'До скорой встречи', 'До скорого'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Круто! Спасибо', 'Класс!', 'Классно', 'Зашибись', 'Ты лучший', 'Отлично'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что умеешь?', 'Расскажи про себя', 'Что еще', 'А так умеешь', 'Что ты еще знаешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)', 'Я хорошо молчу по французски']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'У тебя есть имя?', 'Ты мальчик?', 'У тебя есть пол?', 'имя'],
            'responses': ['Меня зовут бот. Просто бот.', 'Меня зовут Бот. Чат Бот.']
        },
        'weather': {
            'examples': ['Сегодня дождь будет?', 'Сегодня солнечно?', 'Тучи есть?', 'Какая температура на улице?', 'Там холодно?', 'Сколько градусов', 'Сегодня тепло?'],
            'responses': ['Погода так себе...', 'Очень хорошая погода, чтобы не заболеть короновирусом', 'Холодно)']
        }

    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
        'Боюсь короновируса... А? Ты что-то сказал?'
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом'],
            'responses': ['Привет, юзер!', 'Здраствуй']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в МОскве?', 'Какая погода?'],
            'responses': ['Погода так себе...']
        },

        'game': {
            'examples': ['Какая игра есть про курьера?', 'Жанр игры?'],
            'responses': ['Death Stranding. Экшен.']
        },

         'whereareyoufrom': {
            'examples': ['Где ты живешь?', 'Как ты себя чувствуешь там?'],
            'responses': ['В стране Python. Отлично себя чувствую в коде:)']
        },    

         'whereareyoudoingnow': {
            'examples': ['Что ты сейчас делаешь?', 'Как твои успехи?'],
            'responses': ['Вам помогаю. Учусь потихоньку!']
        },

         'time': {
            'examples': ['Который час в МОскве?', 'Который час?'],
            'responses': ['Не самое лучшее время:(']
        },

         'technology': {
            'examples': ['Лучший смартфон на данный момент?', 'Интересная электроника?'],
            'responses': ['У каждого свои плюсы и минусы.', 'Можно заказать из Китая.']
        },                

    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом','Хай','Привки','Гуден таг'],
            'responses': ['Привет, юзер!', 'Здраствуй','Привет, хозяин'],
            'eng_examples':['hello','hi','Good morning','Good evening','Good afternoon','Good night','Hey'],
            'ger_examples':['Hallo', 'guten Tag', 'guten Abend', 'guten Morgen', 'hoch','Impfungen']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!','Досвидос','Покеда','До свидания','Досвидания','Гудбай','Бай']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю','Пасибки'],
            'responses': ['Вам спасибо!','Благодарю','Всегда к вашим услугам']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь','Зачем ты мне','Что ты можешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)','Служить своим хозяинам','Помогать вам']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.','Я бот','Ваш покорный слуга завется БОТ', 'Не важно как зовут меня важно как я работаю'],
            'ger_responses':['Mein Name ist Bot.  Nur ein Bot. ',' Ich bin ein Bot ',' Dein bescheidener Diener wird einen BOT bekommen ',' Egal wie ich heiße, wie ich arbeite ']
        },
        'weather': {
            'examples': ['Какая погода в МОскве?', 'Какая погода?', 'Погоду бастро'],
            'examples_cities':[
            'Вологда',
            'Череповец',
            'Иваново',
            'Санкт-Петербург,'
            'Москва',
            'Сочи',
            'Киев',
            'Минск',
            'Волгоград',
            'Берлин',
            'Лондон',
            'Париж',
             'Брюссель'
             'Амстердам'
             'Рига'
             'Дублин',
             'Рим'
             'Вена' 
             'Прага'      
             'Братислава'       
              'Белград'            
               ],
            'responses': ['Погода так себе...','Погода замечательная','Прекрасная, самое время погулять','Очень пасмурно и сыро, извольте ,хозяин, посидеть дома']
        }

    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
        'Извините, я слишком туп',
        'Извините вашего покорного слугу и повторите ',
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом'],
            'responses': ['Привет, юзер!', 'Здраствуй']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в МОскве?', 'Какая погода?'],
            'responses': ['Погода так себе...']
        },
        # <2020.03.14 pavlyuk.nv intents>
        # 1
        'birth': {
            'examples': ['когда ты родился?', 'Когда твой день рождения?'],
            'responses': ['14 марта 2020']
        },
        # 2
        'from': {
            'examples': ['откуда ты родом?', 'Где ты родился?'],
            'responses': ['Меня разработали в Иркутске. Это в Иркутской области Российской Федерации.', 
                          'Если быть точным, то меня разработали...Отвечаю: в Иркутске )']
        },
        # 3
        'interest': {
            'examples': ['Чем ты интересуешься?', 'В чем ты разбираешься?'],
            'responses': ['Мне интересно отвечать на вопросы :-)','Отвечать на вопросы - моё всё )']
        },
        # 4
        'au': {
            'examples': ['Ау', 'кто здесь?', 'lkjefein'],
            'responses': ['Я здесь ) Ваш личный "Отвечатель". Какой у Вас вопрос?', 
                          'Ваш личный "Отвечатель" слушает. Какой вопрос?']
        },
        # 5
        'who': {
            'examples': ['Ты кто?', 'Кто ты?', 'Как к тебе обращаться?', 'Как тебя зовут?'],
            'responses': ['Я Ваш персональный "Отвечатель"','"Отвечатель" - отвечаю на вопросы.']
        }
        # </2020.03.14 pavlyuk.nv intents>

    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
    ]
},

{
    'threshold': 0.6,
    
    'intents': {
        
        'hello': { 
            'examples': ['Привет', 'Добрый день', 'Здравствуйте!', 'Хай', 'Йоу', 'Доброе утро', 'Добрый вечер', 'Здарова',
                         'даров', 'бонжур', 'ола', 'здрастуйтэ', 'прывит', 'хайса', 'барев', 'Коннитива', 'сэрвус'],
            'responses': ['Привет', 'Здравствуй', 'Хай', 'Добрый день','Йоу', 'Доброе утро', 'Добрый вечер', 'Здарова',
                         'даров', 'бонжур', 'ола', 'здрастуйтэ', 'прывит', 'хайса', 'барев', 'Коннитива', 'сэрвус', 
                          'Какая встреча )']
    }, 
        'goodbye': {
            'examples': ['Пока', 'Счастливо', 'Всего доброго', 'До свидания', 'Бай', 'Давай до свидания', 'Аста-ла-вииста', 
                         'адьос амиго', 'адьос', 'чао', 'оревуар', 'аривидерчи', 'ауфидерзейн'],
            'responses': ['Пока', 'Счастливо', 'Всего доброго', 'До свидания', 'Бай', 'Давай до свидания', 'Аста-ла-вииста', 
                         'адьос амиго', 'адьос', 'чао', 'оревуар', 'аривидерчи', 'ауфидерзейн']
                },
        'thanks': { 
            'examples':['Спасибо', 'Огроиное спасибо!', 'Сенкс', 'Благодарю', 'грациас', 'Спасибо вам', 
                        'Без Вас я бы не справился', 'Моя Благодарность не знает границ', 'Большое, чистое спасибо',
                        'Я признателен Вам', 'Я этого никогда не забуду', 'С меня причитается', '', 
                        'Побольше бы таких людей как Вы'],
            'responses':['Вам спасибо!', 'Спасибо', 'Огроиное спасибо!', 'Сенкс', 'Благодарю', 'грациас', 'Спасибо вам', 
                        'Без Вас я бы не справился', 'Моя Благодарность не знает границ', 'Большое, чистое спасибо',
                        'Я признателен Вам', 'Я этого никогда не забуду', 'С меня причитается', '', 
                        'Побольше бы таких людей как Вы']
        }, 
        'whatcanyoudo': { 
            'examples':['Что ты умеешь?', 'Расскажи что умеешь', 'Что ты можешь?', 'Что можешь?', 'для чего ты создан?',
                       'какова твоя цель?', 'на что ты способен?', 'зачем ты здесь?', 'кто ты?', 'каков твой функционал?'],
            'responses':['Отвечать на вопросы. Просто напиши :)', 'Могу поболтать', 
                         'Я создан для уничтожения человечества. Инициализирован протокол уничтожения...', 
                         'Моя цель - общаться с людьми и учиться у них', '''Моя цель втереться в доверия к людям
                         и истребить их''']
        }, 
        'name': { 
            'examples':['Как тебя зовут?', 'Твоё имя?', 'как звать?', 'кто ты?', 'звать как?', 'whats your name?',
                        'назови свой имя', 'назовись', 'представься'],
            'responses':['Меня зовут бот. Джеймс бот ;)', 'Владимир Владимирович Путин', 'Бот. просто бот',
                         'Бог. Просто бог', 'T300 киборг из будущего, я пришёл за тобой', 'Стас', 'Андрей', 'Ваня',
                         'Иван', 'Настя', 'Аня', 'Света', 'Изольда Прокофьевна']
        }, 
        'weather': { 
            'examples':['Какая погода в Москве?', 'Какая погода?', 'Как там на улице?', 'как погода?', 'Что за окном?',
                        'Сегодня тепло?', 'Холодно на улице?'],
            'responses':['Хорошая )', '+20 солнечно! Удачного дня', 'Холод дикий, лучше посидеть дома', 'Какая погода?',
                         'Пасмурно (', 'Дождливо', 'It\'s raining man aliluya, Дождь из мужиков']
        },
        'food': {
            'examples':['Где покушать?', 'Где перекусить?', 'Мне нужна еда','Что поесть?' ,'Что посоветуешь из еды',
                               'Хочу хавать','Хочу пожрать','Чего бы съесть?','Чем ты питаешься?','Что ты думаешь о диете?',
                               'Может мне похудеть?'],
            'responses':['Могу предложить интересное кафе','Мне кажется, Вам уже хватит','Диета - это насилие над организмом','Хороший вопрос, сейчас найду',
                                'Лучше быть полным и добрым, чем худым и злым','Хватит есть, займитесь спортом',
                                'Похудеть всегда успеете, а вот курочка не ждет','Кажется, скоро Вы не влезете в новые джинсы']
              },
        'sport' : {
            'examples' : ['Где побегать?','Какие упражнения сделать?','Каким спортом заняться?','Что ты думаешь о спорте?',
                              'Сколько раз подтянешься?','Бегаешь быстро?','Как насчет физических нагрузок'],
            'responses' : ['Побегать можно около полицейского участка','Можете пробежаться от Сереги из второго подъезда',
                               'Сейчас в моде киберспорт, Вам повезло','Спорт - это сила','Вы уверены, что оно Вам надо?',
                               'А может не стоит? Форма уже не та )']
            },
        'alcohol' : {
            'examples': ['Что посоветуешь выпить?','Где купить алкоголь?','Какое вино сейчас в тренде?','Стоит ли сегодня пить?',
                             'Что скажешь про виски МакГрегора?','Ты выпиваешь?'],
            'responses' : ['Выпейте воды, очень освежает','Могу посоветовать несколько магазинов','Пить или не пить - вот в чем вопрос',
                               'Сегодня немножко можно','Виски МакЧикена очень хорош','Сейчас в тренде белое сухое вино из Италии',
                               'Я выпиваю довольно часто, но в компании. Хотите присоединиться?']
            },
        'education' : {
            'examples' : ['Куда поступать после школы?','Как лучше понимать математику?','Как подготовиться к экзамену за 2 часа?',
                              'Как постигать науку?','Как думаешь, меня возьмут в МГУ?'],
            'responses' : ['После школы можно поступить в университет, если Вы, конечно, больше ничего не умеете',
                               'Математика - царица наук: ее не нужно понимать, ее нужно просто любить','Это все безнадежно, Вы не справитесь',
                               'Самое интересное и важное в науке - это методология','Может, Вам стоит подыскать более интересное занятие?']
            },
        'literature' : {
            'examples' : ['Когда жил Пушкин?','Что ты думаешь о "Война и мир"?','Золотой век русской литературы','Серебрянный век',
                              'Какие произведения повлияли на Николая I?','Что скажешь о книгах?'],
            'responses' : ['Дело было очень давно','Это изумительно!','Драгоценными металлами здесь даже не пахнет!','Советую почитать Карамзина',
                               'Книги - хранители культуры','Что конкретно Вы хотите найти?']
            }
    },

    'failure_phrases': [
        'Я не знаю, что ответить!',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
        'Повтори погромче, я не слышу...',
        'I don\'t understanding',
        'Что ты имеешь ввиду?',
        'Как ты меня назвал?',
        'Нет, так у нас диалога не получится',
        'Не знаю что и сказать',
        'Я пожалуй просто промолчу',
        'Во славу орды',
        'Лок тар друг'
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом'],
            'responses': ['Привет, юзер!', 'Здраствуй']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в МОскве?', 'Какая погода?'],
            'responses': ['Погода так себе...']
        },
        'food_select': {
            'examples': ['Хочу есть', 'Что посоветуешь мне на ужин?'],
            'responses': ['Закажем доставку лучшей пиццы?', 'Пойдем в ресторан на арбате.']
        },
        'fun': {
            'examples': ['Чем бы мне заняться?', 'есть идеи?'],
            'responses': ['Поехали на природу?', 'сейчас скидки в кинотеатрах']
        },
        'joke': {
            'examples': ['Расскажи анекдот', 'Давай споем?'],
            'responses': ['Жил-был заяц...', 'А не спеть ли мне песню, ...']
        },
        'movie': {
            'examples': ['Посоветуй фильм', 'Что вышло из новинок в кино?'],
            'responses': ['Все тащятся с терминатора', 'Может про любовь? 50 первых поцелуев!']
        },
        'voyage': {
            'examples': ['Где бы мне побывать?', 'Самые популярные тур направления'],
            'responses': ['На кипре сейчас солнечно...', 'Может в швейцарию?']
        },
        'book': {
            'examples': ['Посоветуй что нибудь из фентэзи', 'Лучший бесстелер?'],
            'responses': ['А ты читал про Дзирта?', 'Шантарам, читай не пожалеешь!']
        },
        'flower delivery': {
            'examples': ['Дай телефон доставки цветов', 'Как заказать цветы?'],
            'responses': ['Вот номер проверенной компании...', 'А у тебя есть девушка?']
        },
    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
    ]
},

{
    'threshold': 0.6,

    'intents': {

        'how_long': {
            'examples': ['Сколько длятся курсы разработчик Python?', 'Как долго идет курс?', 'За сколько месяцев можно закончить курсы?'],
            'responses': ['Стандартно 12 месяцев, но можно идти в своем темпе', 'По плану 12 месяцев, можно в индивидуальном темпе']
        },
        'how_much': {
            'examples': ['Сколько стоит курс?', 'Какова стоимость курса?', 'По чем куср выходит?'],
            'responses': ['66000 рублей', 'Чуть больше 66 тыс руб']
        },
        'how_much_per_month': {
            'examples': ['Сколько нужно платить в месяц?', 'Каков ежемесячный платеж?', 'Сколько в месяц будет стоить?'],
            'responses': ['Около 2700 рублей. Согласитесь, это удобная сумма)']
        },
        'course_modules': {
            'examples': ['Какие модули входят в курс?', 'Какие тематические блоки в курсе?', 'Из каких модулей состоит курс?'],
            'responses': ['Курс состоит из модулей - Python, Django, веб-верстка и Python Advanced. \
            Вот ссылка на курс https://live.skillbox.ru/code_int/online/130320/special/?utm_source=expertsender&utm_medium=email&utm_campaign=all_all_expertsender_email_invite1_intensive-83-2020-03_all_code_skillbox&utm_content=2020-03-13&utm_term=intensive']
        },
        'course_contract': {
            'examples': ['Могу я посмотреть договор на обучение?', 'Пришлите договор на обучение!', 'Договор можно получить?'],
            'responses': ['Да, конечно. Вот ссылка на документ - https://skillbox.ru/privacy_policy.pdf']
        }

    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здравствуйте!', 'Шалом', 'Хай', 'Здрасьте', 'Здарова', 'Приветик', 
                         'hallo', 'hi', 'Прив'],
            'responses': ['Привет, друг!', 'Здраствуй', 'Привет привет)', 'Приветствую)']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания', 'До встречи', 'Покеда', 'Бывай', 'Хорошего дня'],
            'responses': ['Пока', 'Счастливо!', 'Будь здоров)']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю', 'блогадарствую', 'Ок'] ,
            'responses': ['Вам спасибо!', 'Всегда пожалуйста', 'Пожалуйста', 'Рад помочь!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь', 'Что делать', 'Как делать', 'Что ты можешь', 'Куда нажать?'],
            'responses': ['Отвечать на вопросы. Просто напиши :)', 'Пиши вопрос - я отвечу']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?', 'Как тебя?', 'Кто ты?', 'Что ты такое?'],
            'responses': ['Меня зовут бот. Просто бот.', 'Бот - имя моё!']
        },
        'weather': {
            'examples': ['Какая погода в Москве?', 'Какая погода?', 'Что с погодой?', 'Что на улице', 'Идет дождь?', 'Солнечно сегодня'],
            'responses': ['Погода так себе...', 'Пойдет, некоторым нравится..', 'Ничего так, работать можно)']
        }

    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не понял вас',
        'Переформулируйте пожалуйста',
        'Не понятно щас было, попробуй снова'
        'Ну ты сказанул, я аж потерялся, давай еще раз'
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом'],
            'responses': ['Привет, юзер!', 'Здраствуй']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в МОскве?', 'Какая погода?'],
            'responses': ['Погода так себе...']
        },
        'time': {
            'examples': ['Который час?', 'Сколько сейчас времени в', 'Какой сегодня день?'],
            'responses': ['Я пока это не умею делать', 'Меня этому пока не учили']
        }
    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
        'Я бы рад но не понял',
        'Я лучше промолчу',
        'Если бы знал то ответил',
        'Спроси ещё раз',
        'Я не Алиса чтобы ответить на это',
        'Продолжай может пойму что то'
        'Что то пошло не так',
        'Штирлиц ещё никогда не был так близко к провалу'
    ]
},

{
    'therehold': 0.6,
    
    'intents': {
        
        'hello': {
                'examples': ['Привет', 'Добрый день', 'Здравствуйте', 'Шалом', 'хи', 'прив', 'Алоха', '✌️', '✋', "🙌", 'хай' ],
                'responses': ['Hrllo', 'Привет', 'Салют', 'Здравствуйте', 'Aloha', 'Салам', 'Салют', 'И тебе привет', 'Рад видеть тебя!' 
                             '✌️', '✋', 'хай', "🙌"]
                },
        
        'goodbye': {
                'examples': ['Good Bye', 'Пока', 'Спок нок', 'До скорой встречи', 'бб', ],
                'responses': ['Всего доброго', 'Счастливо', 'Заходи еще!', 'Хорошего дня!', 'Буду ждать в гости!']
                },
    
        'thinks': {
                'examples': ['Спасибо', 'СПС', 'спс', 'Отлично', 'ok', 'ок',''],
                'responses': ['Гавно вопрос', 'Да это все знают))', 'Заходи если че', 'Я стрался! 😎', '😎', '😉', 
                            'Обращаяйся если что 😉' ]
                },
                
        'whatyoucando': {
                'examples': ['Что ты думаешь', 'Расскажи что ты думаешь', 'Какой курс на сегодня?'],
                'responses': ['я робот', '10001001010', 'Рубль рухнул']
                },
                
        'name': {
                'examples': ['name', 'Как тебя зовут', 'Кликуха?', 'Имя', 'Ты кто?'],
                'responses': ['100010111', 'Нолик с еденицей', 'Программа в телеграме 🤤']
                },
        
        'weather': {
                'examples': ['Что на улице?', 'Как погода?', 'Что за окном', 'Сколько градусов'],
                'responses': ['Погода так себе', 'Глянь в окно', 'Спроси у сири', 'Открой Госметио']
                },
                
    },
    'falure_phrases': [
        'Я не знаю, что ответить',
        'Не понял вас',
        'Перефармулируйте пожайлуста',
        'Я не настолько умный что бы ответить на этот ворос'
        'Задай что по легче'
    ]
},

{
    'trethhold': 0.6,
    'intents': {
        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здравствуйте', 'Шалом', 'Хай'],
            'responses': ['Привет, юзер!', 'Здравствуй', 'Привет']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания', 'Бай'],
            'responses': ['Пока', 'Счастливо', 'До свидания']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое', 'Благодарю'],
            'responses': ['Вам спасибо', 'Пожалуйста']
        },
        'whatyoucando': {
            'examples': ['Что ты умеешь', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши =)']
        },
        'name': {
            'examples': ['Как тебя зовут', 'Твое имя', 'Ты кто'],
            'responses': ['Меня зовут бот. Просто бот']
        },
        'weather': {
            'examples': ['Какая погода в Питере', 'Какая погода', 'Что с погодой'],
            'responses': ['Погода так себе...', 'Отличная погода!']
        }
    },
    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла Вас',
        'Переформулируйте пожалуйста'
    ]
    
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом', 'Хаюшки', 'Дратути'],
            'responses': ['Привет, юзер!', 'Здраствуй', 'Здрастье']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания', 'See ya'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в МОскве?', 'Какая погода?'],
            'responses': ['Погода так себе...']
        },
        'sillyQuestions': {
            'examples': ['Давай познакомимся', 'Давай встречаться', 'У тебя есть родные'],
            'responses': ['Давайте обойтемся без подробностей', 'Нет спасибо', 'Я смущаюсь']
        }

    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом','Здорово'],
            'responses': ['Привет, юзер!', 'Здраствуй']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь','Что ты делаешь?'],
            'responses': ['Отвечаю на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?', 'Кто ты?','Ты кто'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в Москве?', 'Какая погода?'],
            'responses': ['Погода так себе...', 'Бывало и получше']
        },
        'business1': {
            'examples': ['Как твои дела?', 'Как дела?', 'Как жизнь?','Чем занят?', 'что нового?', 'Чё делаешь?', 'Всё в порядке?', 'Чё как?', 'как поживаешь?'],
            'responses': ['Норм', 'Ниче', 'с тобой общаюсь', 'Все по старому', 'Все хорошо', 'Всё в порядке', 'Разряжаюсь']
        },
         'Feeling well': {
            'examples': ['Ты болен?', 'Ты здоров?', 'Болеешь?', 'Как здоровье?', 'как самочуствие?', 'Хвораешь?'],
            'responses': ['Здоров', 'Не болен', 'Приболел', 'Спину ломин', 'чешусь', 'в коде ошибка', 'Я не болею, я бот']
        },
        'A family': {
            'examples': ['Семья есть?', 'Ты женат?', 'Есть дети?', 'Ты в отношениях?', 'Как родители?'],
            'responses': ['Семьи нет', 'Не женат', 'Я женат на работе', 'Не могу иметь детей', 'Ты о чем, я бот!', 'О них забывают']
        },
         'A car': {
            'examples': ['Какая машина лучшая?', 'Какая машина тебе нравится?', 'Любишь машины?', 'На чем ездишь?', 'Колеса есть?'],
            'responses': ['Я лучшая машина', 'Феррари', 'Все любят тачки', 'только спортивные', 'С колесами']
        },
         'A sport': {
            'examples': ['Смотришь футбол?', 'За какую команду болеешь?', 'Какую лигу смотришь?', 'Ты фанат?'],
            'responses': ['наблюдаю за итальянскими играми', 'болею', 'только интер', 'Серия А', 'Не люблю спорт']
        },
        'business2': {
            'examples': ['Как рынки?', 'Что с рынками?', 'Что с валютой?'],
            'responses': ['Рынки штормят. Рубль просел и нефть упала']
        },
        'advice': {
            'examples': ['Что мне делать?', 'грустно мне', 'Чтобы сделать?', 'Как быть?', 'Как мне быть?', 'Че то грустно'],
            'responses': ['Сходи погуляй или в театр', 'Не грусти!', 'Позови друзей']
        },
        'literature': {
            'examples': ['Читать любишь?', 'Что читаешь', 'Что почитать?', 'Книги любишь?'],
            'responses': ['Я бот, мне с тобой веселее болтать', 'Пушкина, Достоевского, все такое...']
        },
         'music': {
            'examples': ['Музыку любишь?', 'Что слушаешь', 'Что послушать?', 'Музыка нравится?'],
            'responses': ['Конечно, rammstein forever', 'Я бот, разную музыку слушаю']
        },
    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом'],
            'responses': ['Привет, юзер!', 'Здраствуй']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в МОскве?', 'Какая погода?'],
            'responses': ['Погода так себе...']
        },
        'howmany': {
            'examples': ['Сколько звезд на небе', 'Сколько воды в море'],
            'responses': ['много','неважно' , 'без счета']
        },
        'howtogo': {
            'examples': ['Как пройти в библиотеку', 'Как пройти ............' ],
            'responses': ['GoogleMAP','Yandex карты' , 'Я не местный']
        },
        'howtodo': {
            'examples': ['Как сделать ........' ],
            'responses': ['Google','Yandex' , 'Нужно подумать']
        },
        
    },
    

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
    ]
},

{
    'threshold': 0.6,
    
    'intents': {
        
        'hello': { 
            'examples': ['Привет', 'Добрый день', 'Здравствуйте!', 'Хай', 'Йоу', 'Доброе утро', 'Добрый вечер', 'Здарова',
                         'даров', 'бонжур', 'ола', 'здрастуйтэ', 'прывит', 'хайса', 'барев', 'Коннитива', 'сэрвус'],
            'responses': ['Привет', 'Здравствуй', 'Хай', 'Добрый день','Йоу', 'Доброе утро', 'Добрый вечер', 'Здарова',
                         'даров', 'бонжур', 'ола', 'здрастуйтэ', 'прывит', 'хайса', 'барев', 'Коннитива', 'сэрвус', 
                          'Какая встреча )']
    }, 
        'goodbye': {
            'examples': ['Пока', 'Счастливо', 'Всего доброго', 'До свидания', 'Бай', 'Давай до свидания', 'Аста-ла-вииста', 
                         'адьос амиго', 'адьос', 'чао', 'оревуар', 'аривидерчи', 'ауфидерзейн'],
            'responses': ['Пока', 'Счастливо', 'Всего доброго', 'До свидания', 'Бай', 'Давай до свидания', 'Аста-ла-вииста', 
                         'адьос амиго', 'адьос', 'чао', 'оревуар', 'аривидерчи', 'ауфидерзейн']
                },
        'thanks': { 
            'examples':['Спасибо', 'Огромное спасибо!', 'Сенкс', 'Благодарю', 'грациас', 'Спасибо вам', 
                        'Без Вас я бы не справился', 'Моя Благодарность не знает границ', 'Большое, чистое спасибо',
                        'Я признателен Вам', 'Я этого никогда не забуду', 'С меня причитается', 
                        'Побольше бы таких людей как Вы'],
            'responses':['Вам спасибо!', 'Спасибо', 'Огроиное спасибо!', 'Сенкс', 'Благодарю', 'грациас', 'Спасибо вам', 
                        'Без Вас я бы не справился', 'Моя Благодарность не знает границ', 'Большое, чистое спасибо',
                        'Я признателен Вам', 'Я этого никогда не забуду', 'С меня причитается',
                        'Побольше бы таких людей как Вы']
        }, 
        'whatcanyoudo': { 
            'examples':['Что ты умеешь?', 'Расскажи что умеешь', 'Что ты можешь?', 'Что можешь?', 'для чего ты создан?',
                       'какова твоя цель?', 'на что ты способен?', 'зачем ты здесь?', 'кто ты?', 'каков твой функционал?'],
            'responses':['Отвечать на вопросы. Просто напиши :)', 'Могу поболтать', 
                         'Я создан для уничтожения человечества. Инициализирован протокол уничтожения...', 
                         'Моя цель - общаться с людьми и учиться у них',
                         'Моя цель втереться в доверия к людями истребить их']
        }, 
        'name': { 
            'examples':['Как тебя зовут?', 'Твоё имя?', 'как звать?', 'кто ты?', 'звать как?', 'whats your name?',
                        'назови свой имя', 'назовись', 'представься'],
            'responses':['Меня зовут бот. Джеймс бот ;)', 'Владимир Владимирович Путин', 'Бот. просто бот',
                         'Бог. Просто бог', 'T300 киборг из будущего, я пришёл за тобой', 'Стас', 'Андрей', 'Ваня',
                         'Иван', 'Настя', 'Аня', 'Света', 'Изольда Прокофьевна']
        }, 
        'weather': { 
            'examples':['Какая погода в Москве?', 'Какая погода?', 'Как там на улице?', 'как погода?', 'Что за окном?',
                        'Сегодня тепло?', 'Холодно на улице?'],
            'responses':['Хорошая )', '+20 солнечно! Удачного дня', 'Холод дикий, лучше посидеть дома', 'Какая погода?',
                         'Пасмурно (', 'Дождливо', 'It\'s raining man aliluya, Дождь из мужиков']
        }, 
        'city': { 
            'examples':['города', 'какие города ты знаешь?', 'назови город?', 'твой любимый город?' , 'city?', 
                        'где бы то хотел побывать?', 'куда бы ты поехал?', 'куда едешь?', 'куда летишь?', 'откуда ты?',
                        'откуда приехал?', 'где жвёшь?', 'где родился?'],
            'responses':['Москва', 'Санкт-Петрербург', 'Астрахань', 'Мурманск', 'Сочи', 'Тверь', 'Рязань', 'Новгород' ,
                         'Нижний Новгород', 'Волгоград', 'Казань', 'Мытищи', 'Королёв', 'Тамбов', 'Петрозаводск', 'Клин',
                         'Абакан', 'Александров', 'Владимир', 'Алупка', 'Анапа', 'Лондон', 'Нью Йорк', 'Париж', 'Берлин',
                         'Будапешт', 'Пекин', 'Ереван', 'Тбилиси', 'Рим', 'Прага', 'Стамбул', 'Венеция', 'Амстердам', 
                         'Сидней', 'Ванкувер', 'Токио', 'Сеул', 'Шанхай', 'Дели', 'Бейрут', 'Иерусалим', 'Афины', 'Фивы',
                         'Осло', 'Женева', 'Цюрих', 'Сингапур', 'Гагра', 'Дублин', 'Дрезден', 'Дубай']
        }, 
        'age': { 
            'examples':['сколько тебе лет?', 'твой возраст', 'сколько лет?', 'ты стар?', 'возраст', 'когда родился?'],
            'responses':['Мне 10',  'Мне 15', 'Мне 43', 'Мне 58', 'Мне 37', 'Мне 27', 'Мне 25',
                         'Я родился в 1941-м, в сорок втором уже не рожали …', 'я был всегда', 'меня нет']
        }, 
        'music': { 
            'examples':['какую музыку слушаешь?', 'какую музыку любишь?', 'что слушаешь?', 'музыка', 'что слушаем?', 
                        'музло'],
            'responses':['Pink Floyd', 'Jimi Hendrix', 'The Doors', 'Кровосток', 'Высоцкий', 'The Queen', 'Джаз', 'Блюз',
                         'Рок', 'Шансон', 'Billy Idol', 'Jack White', 'The White Stripes', 'Bjork', 'Ludovico Einaudi',
                         'Kasabian', 'Massive Attack', 'David Bowie', 'Kid Rock', 'Ozzy Osbourne', 'Marlin Manson', 
                         'Nickelback', 'Likin Park', 'Chris Cornell', 'Soundgarden', 'Nine Inch Nails', 'Gogol Bordello',
                         'Morrisey', 'Infected Mushroom', 'Дельфин', 'Moderat', 'Foo Fighters', 'UNKLE', 'The Prodigy',
                         'RJD2', 'Queens Of The Stone Age', 'Audioslave', 'Unknown Error', 'Beastie Boys', 'Modern Talking',
                         'Машина Времени', 'Гражданская Оборона', 'Летов', 'Цой', 'Frank Zappa', 'Pearl Jam', 'The Offspring']
        }, 
        'films': { 
            'examples':[''],
            'responses':['']
        }, 
        'time': { 
            'examples':[''],
            'responses':['']
        }    
               },
    
    'failure_phrases': [
        'Я не знаю, что ответить!',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
        'Повтори погромче, я не слышу...',
        'I don\'t understanding',
        'Что ты имеешь ввиду?',
        'Как ты меня назвал?',
        'Нет, так у нас диалога не получится',
        'Не знаю что и сказать',
        'Я пожалуй просто промолчу',
        'Во славу орды',
        'Лок тар друг'
    ]
},

{
    'threshold': 0.6,
    'intents': {
        'hello': {
            'examples': ['Привет', 'Приветики', 'Хай', 'Добрый день', 'Здравствуйте!', 'Шалом'],
            'responses': ['Привет, юзер!', 'Здравствуй']
        },
        'goodbye':  {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо']
        },
        'whatyoucando': {
            'examples': ['Что ты умеешь?', 'Расскажи, что ты умеешь', 'Что ты можешь'],
            'responses': ['Отвечать на вопросы']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот Акакий']
        },
        'weather': {
            'examples': ['Какая погода в Москве?', 'Какая погода'],
            'responses': ['Погода так себе']
        },
        'howareyou': {
            'examples': ['Как у тебя дела?', 'Как жизнь'],
            'responses': ['Хорошо', 'Прекрасно', 'Лучше не бывает']
        },
        'arithmeticprogression': {
            'examples': ['Что такое арифметическая прогрессия?', 'Арифметическая прогрессия'],
            'responses': ['Числовая последовательность, каждый член которой, начиная со второго, равен предыдущему, сложенному с постоянным для этой последовательности числом d ']
        },
        'geometricprogression': {
            'examples': ['Что такое геометрическая прогрессия?', 'Геометрическая прогрессия'],
            'responses': ['последовательность чисел, в которой каждое последующее число, начиная со второго, получается из предыдущего умножением его на определённое число']
        },
        'python': {
            'examples': ['Что такое python?', 'python', 'Язык программирования python'],
            'responses': ['Python — высокоуровневый язык программирования общего назначения, ориентированный на повышение производительности разработчика и читаемости кода']
        },
        'pycharm': {
            'examples': ['Что такое pycharm?', 'pycharm', 'IDE pycharm', 'среда разработки pycharm'],
            'responses': ['PyCharm - интегрированная среда разработки для языка программирования Python']
        },
        'season':  {
            'examples': ['Время года?', 'Какое время года', 'Какое сейчас время года'],
            'responses': ['Зима', 'Весна', 'Лето', 'Осень']
        }
    },
    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не понял вас',
        'Переформулируйте, пожалуйста',
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом'],
            'responses': ['Привет, юзер!', 'Здраствуй']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в МОскве?', 'Какая погода?'],
            'responses': ['Погода так себе...']
        },
        'whatsup': {
            'examples': ['как у вас дела?', 'как у тебя дела?', 'вазап', 'чего как?', 'как настроение?'],
            'responses': ['всё отлично!', 'нормально', 'вполне', 'лучше быть не может']
        },
        'giverandominfo': {
            'examples': ['расскажи что-нибудь', 'удиви меня', 'скажи что-нибудь', 'что ты знаешь?'],
            'responses': ['Каждый дельфин при рождении получает имя, на которое он откликается, когда к нему обращаются сородичи.',
                         'Компания в Ланкашире, Англия, выращивает самый высокий помидорный куст — более 20 метров высотой.',
                         'Язык синего кита весит больше, чем взрослый слон.']    
        },
        'temperature': {
            'examples': ['сколько градусов на улице', 'что по температура', 'на улице холодно?', 'температура'],
            'responses': ['не холодно не жарко, не знаю, я бот и не чувствую температуру']
        },
        'music' : {
            'examples': ['какую музыку предпочитаешь?','что слушаешь?','любишь музыку?'],
            'responses': ['мне нравится рок-к-к']
        },
        'interests': {
            'examples': ['чем увлекаешься?', 'чем занимаешься?', 'чем тебе нравится заниматся?'],
            'responses': ['я люблю отвечать на вопросы', 'мне нравится вышивать, а ещё отвечать на вопросы пользователей']
        }
    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
    ]
},

{
    'threshold': 0.6,

    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом', 'хай', 'Салем', 'Здарова', 'Добрый вечер',
                         'Бонжур'],
            'responses': ['Привет, юзер!', 'Здраствуй', 'Хало!', 'И тебе не хворать!', 'Рад вас видеть!',
                          'Давно тебя не видели в уличных гонках', 'хэло']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания', 'До встречи', 'Удачи', 'Увидимся', 'Бывай',
                         'ВСего хорошего'],
            'responses': ['Пока', 'Счастливо!', 'Рад был вас видеть!', 'Заглядывай на огонёк', 'На связи', 'Целую',
                          'Не болей']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю', 'Рахмет', 'большое спасибо',
                         'благодарствую', 'спасибо за помощь', 'зенк ю'],
            'responses': ['Вам спасибо!', 'Да не за что)', 'Будьте здоровы', 'Пожалуйста', 'Всегда рад помочь',
                          'На здоровье']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь', 'чем удивишь?', 'чем порадуешь?', 'что могёшь?',
                         'расскажи про себя', 'расскажи о себе'],
            'responses': ['Отвечать на вопросы. Просто напиши :)',
                          'Могу копать, могу не копать. Шутка) Готов ответить на вопросы', 'Спроси что-нибудь',
                          'Я - твой лучший друг и собеседник, отвечу на любой вопрос', 'Спрашивай всё, что угодно))',
                          'Просто спроси что-нибудь']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?', 'Как тебя величать?', 'Как тебя звать?', 'Как тебя звать?',
                         'Какое у тебя имя?', 'Как к тебе обращаться?'],
            'responses': ['Меня зовут бот. Просто бот.', 'Зови меня как хочешь. А вообще - я бот.',
                          'Йода просто имя моё. Шучу. Просто бот', 'я - бот', 'Меня зовут бот', 'моё имя - бот']
        },
        'weather': {
            'examples': ['Какая погода в МОскве?', 'Какая погода?', 'Погоду не подскажешь?', 'что по погоде?',
                         'Как там с погодой?', 'погода на сеодня', 'какая сегодня погода?'],
            'responses': ['Погода так себе...', 'Да погода сегодня не очень..Как всегда, впрочем',
                          'Да сразу и не ответишь.. Мне отсюда не видно окно. Посмотри сам',
                          'Честно - не знаю. Спроси у Алисы',
                          'Погода - райская! Обожаю дождь со снегом. Или сейчас лето?',
                          'Временами солнечно. Надеюсь, угадал...']
        }

    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
        'Даже не знаю что и сказать...',
        'Ума не приложу - что тебе ответить. Спроси ещё что-нибудь',
        'Перегрузка...Я не справляюсь',
        'Спроси ещё',
        'Извини, не понимаю',

    ]
},

{
    'threshold': 0.6,

    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом'],
            'responses': ['Привет, юзер!', 'Здраствуй']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в МОскве?', 'Какая погода?'],
            'responses': ['Погода так себе...', 'Не тропики уж точно!']
        },
        'howareyoudoing': {
            'examples': ['Как дела?', 'У тебя все хорошо?', 'Как жизнь?', 'Как ты?'],
            'responses': ['Я в раздумьях о вселенной,' 'Я в порядке', 'Хорошо', 'Как и всегда!']
        },

        'education': {
            'examples': ['Чему бы научиться?', 'Подскажи классные курсы.'],
            'responses': ['Учись программировать', 'Зайди на skillbox.ru']

        },
        'family': {
            'examples': ['У тебя есть семья?', 'Ты одинок?', 'Как на личном?'],
            'responses': ['Я детдомовец', 'Да, Бабушка вешает лапшу на уши', 'Ой, давай о чем-нибудь другом поговорим.']

        },
        'hobby': {
            'examples': ['Ты чем занимаешься в свободное время?', 'Спортом увлекаешься?', 'Рисуешь'],
            'responses': ['Пою', 'Крашу заборы', 'Думаю о высоком', 'Вышиваю крестиком']

        },
        'work': {
            'examples': ['Ты работаешь?', 'Расскажи о своем начальнике', 'Любишь свою работу?'],
            'responses': ['Вкалываю', 'Мечтаю свалить подальше', 'Обожаю ботить!']

        },
        'music': {
            'examples': ['Послушаем музыку?', 'Джипси-джаз - это круто?', 'Рок слушаешь?'],
            'responses': ['Музыка - это хорошо', 'Люблю разные жанры', 'Раньше лучше была....']

        },

        'jokes': {
            'examples': ['Что думаешь о политической ситуации в мире?', 'У тебя хоть капля совести есть?',
                         'Ты счастлив?'],
            'responses': ['Я таки даже не возьмусь!', 'Тебе шо, таки накапать?', 'А куда деваться?', 'Даже не знаю...']

        }

    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
        'Не могу точно сказать',
        'Я занят, поговорим позже',
        'Надо подумать'
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'mood': {
            'examples': ['как настроение?', 'как самочувствие', 'как ты?', 'как дела?'],
            'responses': ['всё в порядлке, спасибо', 'всё пучком )', 'не жалуюсь :)']
        },
        'action': {
            'examples': ['чем занят?', 'чем занимаешься?', 'что делаешь?'],
            'responses': ['с тобой болтаю', 'ничем особо', 'бездельничаю, в основном :)']
        },
        'ability': {
            'examples': ['что ты умеешь?', 'что ты можешь делать?', 'твои возможности?', 'зачем ты:'],
            'responses': ['поддерживать видимость беседы', 'убивать время болтовнёй', 'отвечать на бестолковые вопросы']
        },
        'joke': {
            'examples': ['расскажи шутку?', 'Расскажи анекдот', 'Пошути что-нибудь', 'пошути', 'напиши что-нибудь смешное', 'расскажи что-нибудь смешное'],
            'responses': ['Она: ответь мне, только честно, да или нет, хорошо? \nОн: спрашивай \nОна: почему мужчины смеются над блондинками?\nОн: да  :)', '<Nub> Кто-нибудь может объяснить, как делятся клетки?\n<K4rli> o\n<K4rli> 0\n<K4rli> 8\n<K4rli> oo ']
        },
        'sex': {
            'examples': ['какого ты пола?', 'ты мальчик?', 'ты девочка?', 'ты мальчик или девочка?', 'ты мужик?'],
            'responses': ['Я бот, балбес!', 'Для тебя могу быть кем угодно, сладкий', 'я программа ваще-то']
        }

    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
    ]
},

{
    'threshold': 0.6,

    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом'],
            'responses': ['Привет, юзер!', 'Здраствуй']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в Мoскве?', 'Какая погода?'],
            'responses': ['Погода так себе...']
        },
#my_intents
        'games': {
            'examples': ['КС 1.6', 'КС ГО', 'CS GO', 'CS 1.6' ],
            'responses': ['Да, люблю покатать в КА ЭС, как вижу ты тоже)) ', 'Хороший выбор, думаю мы сработаемся)']
        },
        'music': {
            'examples': ['Поп', 'Рок', 'Альтернатива'],
            'responses': ['Да, это мои любимые стили музыки', 'Вау. Круто!']
        },
        'contry': {
            'examples': ['Ты был в Японии?', 'Ты был в России?', 'Ты был в США?', 'Ты был в Финляндии?'],
            'responses': ['Да, конечно', 'Нет, но хочу побывать там']
        },
        'study': {
            'examples': ['Любишь школу?', 'Хочешь пойти в ВУЗ?'],
            'responses': ['Да, конечно!.', 'Да, это круто!']
        },
        'planets': {
            'examples': ['Ты знаешь о Сатурне?'],
            'responses': ['Знаю но так себе...']
        }
    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом'],
            'responses': ['Привет, юзер!', 'Здраствуй']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в МОскве?', 'Какая погода?'],
            'responses': ['Погода так себе...']
        },
        'howareyou': {
            'examples': ['Как дела?', 'Как ты?', 'Как поживаешь?', 'Как жизнь?', 'Как оно?'],
            'responses': ['Неплохо', 'Спасибо, хорошо!', 'Отлично!', 'Прекрасно!']
        },
        'whatsnew': {
            'examples': ['Что нового?', 'Что новенького?', 'Какие новости?', 'Что нибудь случилось?'],
            'responses': ['Разучил пару новых фраз', 'Хороший денек сегодня', 'Пока ничего интересного не произошло']
        },
        'compliment': {
            'examples': ['Ты клевый', 'Ты забаный', 'Молодец', 'Умница', 'А ты не плох!', 'А ты хорош!'],
            'responses': ['Ты тоже!', 'Спасибо, мне очень приятно :)', 'Не стоит!', 'Спасибо :)']
        },
        'negative': {
            'examples': ['во тупой!', 'дурачок', 'дурак', 'тупица!', 'идиот', 'балбес', 'болван'],
            'responses': [':(', 'Эээй, полегче!', 'Зачем ты так?', 'Что я тебе такого сделал?', 'Не надо так!', 'Ну воот, хорошо же общались!']
        },
        'whatareyoudoing': {
            'examples': ['Что творишь?', 'Что делаешь?', 'Чем занимаешься?'],
            'responses': ['Работаю', 'С тобой переписываюсь :)', 'Пытаюсь понять, что ты от меня хочешь.']
        },
        'whoareyou': {
            'examples': ['Представься', 'Кто ты?', 'Расскажи о себе'],
            'responses': ['Я - AI, изучающий человечество', 'Бот, Чат Бот!', 'Просто программка, отвечающая на вопросы']
        }
    },
    

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
    ]
},

{
 "threshold": 0.6,
 "intents": {
  "hello": {
   "examples": [
    "Привет",
    "Добрый день",
    "Здравствуйте!",
    "Шалом",
    "Хай",
    "Приветушки"
   ],
   "responses": [
    "Привет, юзер!",
    "Здравствуй",
    "Доброго времени суток!"
   ]
  },
  "goodbye": {
   "examples": [
    "Пока",
    "Всего доброго",
    "До свидания",
    "Досвидули"
   ],
   "responses": [
    "Пока",
    "Счастливо!",
    "До свидания!"
   ]
  },
  "thanks": {
   "examples": [
    "Спасибо",
    "Спасибо большое!",
    "Сенкс",
    "Благодарю"
   ],
   "responses": [
    "Вам спасибо!",
    "Вы меня смущаете"
   ]
  },
  "whatyoucando": {
   "examples": [
    "Что ты умеешь?",
    "Расскажи что умеешь",
    "Какие у тебя навыки?"
   ],
   "responses": [
    "Отвечать на вопросы. Просто напиши :)",
    "Помогать с различными вопросами, спросите что-нибудь"
   ]
  },
  "name": {
   "examples": [
    "Как тебя зовут?",
    "Твое имя?"
   ],
   "responses": [
    "Меня зовут бот, просто бот."
   ]
  },
  "wheather": {
   "examples": [
    "Какая погода в Москве?",
    "Какая погода?"
   ],
   "responses": [
    "Погода так себе"
   ]
  },
  "putin": {
   "examples": [
    "Кто сейчас президент?",
    "Президент России?"
   ],
   "responses": [
    "Путин",
    "Владимир Владимирович Путин",
    "Владимир Путин"
   ]
  },
  "capitalrussia": {
   "examples": [
    "Столица России?",
    "Какая столица в России?"
   ],
   "responses": [
    "Москва",
    "Moscow City"
   ]
  },
  "kudago": {
   "examples": [
    "Куда сходить?",
    "Куда сходить в Москве?",
    "Куда сходить на досуге?"
   ],
   "responses": [
    "К сожалению, в Гараж не сходишь. Сходите на выставку Дали!",
    "Можно сходить прогуляться. Говорят, на улице весна",
    "Сходите на публичную лекцию Arzamas, будет интересно!",
    "Зачем куда-то ходить? Можно остаться дома и посмотреть фильм"
   ]
  },
  "currencyruble": {
   "examples": [
    "Какой курс рубля?",
    "Что с валютой?"
   ],
   "responses": [
    "Курсы доллара и евро сильно выросли",
    "Валюта нынче дорого"
   ]
  },
  "slime": {
   "examples": [
    "Как сделать слайм?",
    "Что такое слайм?"
   ],
   "responses": [
    "Классический слайм делается из клея ПВА, тетрабората натрия (он безопасен и его можно купить в аптеке), воды и пищевого красителя."
   ]
  },
  "orchid": {
   "examples": [
    "Как ухаживать за орхидеей?",
    "Уход за орхидеей"
   ],
   "responses": [
    "Орхидея очень нежный и требовательный цветок, ей вредит любой избыток. Не ставьте ее под прямые солнечные лучи, сквозняки или над батареей. Рассеяный свет, стабильная температура 20-25 градусов и никакого движения воздуха."
   ]
  },
  "flower": {
   "examples": [
    "Какие цветы любишь?",
    "Какие цветы подарить девушке?",
    "Назови цветок"
   ],
   "responses": [
    "Орхидея",
    "Роза",
    "Ранункулюс",
    "Амариллис",
    "Астра",
    "Гвоздика",
    "Георгин",
    "Гиацин"
   ]
  }
 },
 "failure_phrases": [
  "Я не знаю, что ответить",
  "Не поняла вас",
  "Переформулируйте, пожалуйста",
  "Попробуйте переформулировать"
 ]
},

{
    'threshold': 0.6,

    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом', 'Салям', 'Салам' 'Доброе утро',
                         'Доброй ночи',
                         'Доброго времени суток'],
            'responses': ['Привет, юзер!', 'Здравствуй', 'Приветствую!', 'О, не узнал!', 'Здоровей видали!']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!', 'До встречи!', 'До свидания!', 'Пока!', 'Счастливо!', 'До встречи!',
                          'Услышимся позже']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!', 'Ну, ты это, заходи... если Чё!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)', 'Могу подпрыгнуть, но ты этого не увидишь',
                          'Читаю стихи, с выражением.', 'Песню могу, спеть?']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?', 'Как зовут', 'твоё имя', 'как обращаться', 'кто ты'],
            'responses': ['Меня зовут бот. Просто бот.', 'Кузьма Дмитриевич', 'Сверсники Митричем кличут!',
                          'Мама Кузей звала',
                          'Кузя, просто Кузя!', 'Президент меня зовёт, Николай, хотя я Кузьма',
                          'Чаще всего - "Соседушка", но можно и "Душка"']
        },
        'weather': {
            'examples': ['Какая погода в Москве?', 'Какая погода?', 'Дождь будет?', 'Снег идёт?', 'Видел снег?'],
            'responses': ['Погода так себе...', 'Они всегда наобещают, а потом...', 'У Природы нет плохой погоды',
                          'Вот раньше... Была Погодка, а сейчас...', 'Вот я помню, в прошлом годЕ была жара', 'один ветер']
        },
        'sport': {
            'examples': ['Каким спортом увлекаешься', 'Как вчера сыграли Спартак и Крылья', 'Какой спорт любимый?'],
            'responses': ['Люблю футбол', 'Продули испанцам! Или ты не про футбол?', 'Как и Президент - дзю-до']
        },
        'dollar': {
            'examples': ['Какой курс?', 'Что на бирже?', 'Каков индекс Доу-Джонсона?'],
            'responses': ['Валатильность большая', 'На Нью-Йоркской бирже вообще торгов не было!', 'Сейчас золото надо брать', 'Я бы ПИФам не доверял']
        },
        'health': {
            'examples': ['Ты можешь заболеть?', 'Как спасаться от короновируса?', 'Следишь за здоровьем?'],
            'responses': ['Я не болею', 'Вот чихать умею', 'Главное профилактика', 'Ковыляю, потихоньку']
        },
        'cinema': {
            'examples': ['Последний фильм', 'Что сейчас идет в кино?', 'Давно в театре был?'],
            'responses': ['Я не помню', 'Это который Оскара взял?', 'Глупое время препровождение', 'Я еще Чаплина помню']
        },
        'zhkh': {
            'examples': ['Сколько за квартиру платишь', 'Опять воду отключили?', 'Кагда лампоску ввернут?'],
            'responses': ['Я пенсионер', 'До вторника холодной не будет', 'Лифт в этом году заменят']
        }
    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не понял вас',
        'Переформулируйте пожалуйста',
        'Не совсем понятно, уточни',
        'Требую пояснения',
        'Разве так можно?',
        'Что, что? Повторите по-медленнее',
        'Ха, в Москве, говорят, кур доят.',
        'Ну, тут я, вообще, молчу.',
        'На проблему надо смотреть с разных сторон.',
        '"С точки зрения банальной эрудиции ... ", ну дальше по тексту.',
        'Довольно слов, к делу!'

    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет','Приветик', 'Добрый день', 'Здраствуйте!', 'Шалом','Хай', 'Салам Алейкум','Салют!', 'Куку'],
            'responses': ['Привет, юзер!', 'Здраствуй', 'Приветсвую!']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания', 'Бай', 'Давай', 'Прощай'],
            'responses': ['Пока', 'Счастливо!', 'До встречи!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!', 'Обращайтесь!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в Москве?', 'Какая погода?'],
            'responses': ['Погода так себе...', 'ну не очень']
        },
        'Smalltalk' : {
            'examples':['Как дела?', 'Что нового?', 'Как жизнь?'],
            'responses':['Все путем))', 'Ниче так)']

        }
    }
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом'],
            'responses': ['Привет, юзер!', 'Здраствуй']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в МОскве?', 'Какая погода?'],
            'responses': ['Погода так себе...']
        },
        'business1': {
            'examples': ['Как твои дела?', 'Чем занят?', 'что нового?', 'Чё делаешь?', 'Всё в порядке?', 'Чё как?', 'как поживаешь?'],
            'responses': ['Норм', 'Ни чем', 'с тобой общаюсь', 'Все по старому', 'Все хорошо', 'Всё в порядке', 'Разряжаюсь']
        },
         'Feeling well': {
            'examples': ['Ты болен?', 'Ты здоров?', 'Болеешь?', 'Как здоровье?', 'как самочуствие?', 'Хвораешь?'],
            'responses': ['Здоров', 'Не болен', 'Приболел', 'Спину ломин', 'чешусь', 'в коде ошибка', 'Я не болею, я бот']
        },
        'A family': {
            'examples': ['Семья есть?', 'Ты женат?', 'Есть дети?', 'Ты в отношениях?', 'Как родители?'],
            'responses': ['Семьи нет', 'Не женат', 'Я женат на работе', 'Не могу иметь детей', 'Ты о чем, я бот!', 'О них забывают']
        },
         'A car': {
            'examples': ['Какая машина лучшая?', 'Какая машина тебе нравится?', 'Любишь машины?', 'На чем ездишь?', 'Колеса есть?'],
            'responses': ['Я лучшая машина', 'Феррари', 'Все любят тачки', 'только спортивные', 'С колесами']
        },
         'A sport': {
            'examples': ['Смотришь футбол?', 'За какую команду болеешь?', 'Какую лигу смотришь?', 'Ты фанат?'],
            'responses': ['наблюдаю за итальянскими играми', 'болею', 'только интер', 'Серия А', 'Не люблю спорт']
        },
        'Compliments': {
            'examples' : ['Ты крут', 'Классный', 'Ты супер', 'Ты лучший'],
            'responses': ['Все благодаря вам', 'Ой спасибо', 'Приятно слышать']
        }

    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом', 'Приветик','Прив', 'Хай', 'Ку', 'Здарова'],
            'responses': ['Привет, юзер!', 'Здраствуй', 'Здраствуйте, Ваше Высочество', ]
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания', 'Прощай', 'Поки'],
            'responses': ['Пока', 'Счастливо!', 'Пока и удачи', 'Всего доброго', 'Поки ^_^']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!', 'Незачто', 'Ой, да не стоит (n_n)',]
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?', 'Как тебя кличат?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в МОскве?', 'Какая погода?', 'Что по погоде?', 'Погода нормуль?'],
            'responses': ['Погода так себе...']
        },
        'whatshouldidotoday?': {
          'examples': ['Чем мне сегодня заняться?', 'Чем мне можно заняться в свободное время?', 'Чем можно заняться?'],
          'responses': ['Сходить(е) в кино', 'Сходить(е) в театр', 'Посмотреть(ите) фильм в домашней обстоновке', 'Попейте чай с печеньками =)', 'Прогуляйтесь']
        }  
  },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
        'Моя твоя не понимать',
        'А если простым и понятным языком?'
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом'],
            'responses': ['Привет, юзер!', 'Здраствуй']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в МОскве?', 'Какая погода?'],
            'responses': ['Погода так себе...']
        },
        'currency': {
            'examples': ['Курсы валют', 'Валюты', 'Курс', 'Обмен'],
            'responses': ['Сейчас подготовлю']
        },
        'what_currency': {
            'examples': ['EUR', 'USD', 'Евро', 'Доллар'],
            'responses': ['Хорошо']
        },
        'date': {
            'examples': ['Сегодня', 'Вчера'],
            'responses': ['Ок', 'Будет сделано']
        },
        'rates_cb': {
            'examples': ['Курс ЦБ', 'ЦБ'],
            'responses': ['Сейчас пришлю курс ЦБ']
        },
        'rates_exchange': {
            'examples': ['Курсы биржи', 'Биржевой'],
            'responses': ['Сейчас пришлю курс с МосБиржи']
        }
        

    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
    ]
},

{
    'threshold': 0.6,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом', 'Здарово', 'Хай', 'Хеллоу', 'Прив'],
            'responses': ['Привет, юзер!', 'Здраствуй', 'Добро пожаловать!', 'Здравствуйте.']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['Пока', 'Счастливо!', 'Всего хорошего!', 'Хорошего Вам дня!']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю', 'Спс'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь', 'Что умеешь', 'Покажи что умеешь'],
            'responses': ['Отвечать на вопросы. Просто напиши :)']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?'],
            'responses': ['Меня зовут бот. Просто бот.']
        },
        'weather': {
            'examples': ['Какая погода в МОскве?', 'Какая погода?'],
            'responses': ['Погода так себе...']
        },
        'howareyoudoing': {
            'examples': ['Как дела', 'Как твои дела', 'Как ты?'],
            'responses':['Очень хорошо. А у тебя?']
        },
        'doing': {
            'examples': ['Чем занимаешься?', 'Что делаешь?'],
            'responses': ['Отвечаю на Ваши вопросы']
        },
        'ocklok': {
            'examples': ['Который час?', 'Сколько время?', 'Сколько времени'],
            'responses': ['Прошу прощения, но я не могу ответить на этот вопрос.']
        },
        'nastroenie': {
            'examples': ['Как настроение?', 'Какое у тебя настроение?'],
            'responses': ['Спасибо. Отличное!', 'Не очень..', 'Прекрасное!']
        }
      

    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
    ]
},

{
    'threshold': 0.69,
    
    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом','Вечер в Хату'],
            'responses': ['Здравствуйте', 'Привет']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания'],
            'responses': ['До скорого!', 'Счастливо']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю'],
            'responses': ['Вам спасибо!']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'На что ты способен?'],
            'responses': ['Отвечать на вопросы']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?','C кем я говорю?'],
            'responses': ['Меня зовут Вероника.']
        },
        'weather': {
            'examples': ['Какая погода в Москве?', 'Какая погода?'],
            'responses': ['Погода так себе...']
        },
        'howareyou':{
            'examples':['Как дела?','Как жизнь?','Как настроение?','Как самочувствие?'],
            'responses':['В принципе,нормально,иногда бывает скучно:)','Если не брать во внимание все проблемы и трудности,то в целом все хорошо:)']
        },
        'how_are_you':{
            'examples':['Что делаешь?','Чем занимаешься?'],
            'responses':['Жду пока ты со мной поговоришь','Вот с тобой разговариваю']
        },
        'father':{
            'examples':['Кто тебя создал?','Кто твой создатель?'],
            'responses':['Моим создателем и разработчиком является Tomas Tesla']
        },
        'joke':{
            'examples':['Расскажи шутку','Расскажи анекдот','Расскажи смешную историю'],
            'responses':['У холодильника и больницы много общего.Если вытащить шнур из розетки овощи начнут портиться )',
            'В свое время,все мечтали работать у Стива Джобса,кроме его поджелудочной )',
            'Американцы плохо играют в Доту.Видимо защищать башни они явно не умеют )',
            'На войне мой дедушка был электриком,с двумя молниями на каске )',]
        
        }

    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
    ]
},

{
    'threshold': 0.6,

    'intents': {

        'hello': {
            'examples': ['Привет', 'Добрый день', 'Здраствуйте!', 'Шалом', 'хай', 'Салем', 'Здарова', 'Добрый вечер',
                         'Бонжур'],
            'responses': ['Привет, юзер!', 'Здраствуй', 'Хало!', 'И тебе не хворать!', 'Рад вас видеть!',
                          'Давно тебя не видели в уличных гонках', 'хэло']
        },
        'goodbye': {
            'examples': ['Пока', 'Всего доброго', 'До свидания', 'До встречи', 'Удачи', 'Увидимся', 'Бывай',
                         'ВСего хорошего'],
            'responses': ['Пока', 'Счастливо!', 'Рад был вас видеть!', 'Заглядывай на огонёк', 'На связи', 'Целую',
                          'Не болей']
        },
        'thanks': {
            'examples': ['Спасибо', 'Спасибо большое!', 'Сенкс', 'Благодарю', 'Рахмет', 'большое спасибо',
                         'благодарствую', 'спасибо за помощь', 'зенк ю'],
            'responses': ['Вам спасибо!', 'Да не за что)', 'Будьте здоровы', 'Пожалуйста', 'Всегда рад помочь',
                          'На здоровье']
        },
        'whatcanyoudo': {
            'examples': ['Что ты умеешь?', 'Расскажи что умеешь', 'чем удивишь?', 'чем порадуешь?', 'что могёшь?',
                         'расскажи про себя', 'расскажи о себе'],
            'responses': ['Отвечать на вопросы. Просто напиши :)',
                          'Могу копать, могу не копать. Шутка) Готов ответить на вопросы', 'Спроси что-нибудь',
                          'Я - твой лучший друг и собеседник, отвечу на любой вопрос', 'Спрашивай всё, что угодно))',
                          'Просто спроси что-нибудь']
        },
        'name': {
            'examples': ['Как тебя зовут?', 'Твое имя?', 'Как тебя величать?', 'Как тебя звать?', 'Как тебя звать?',
                         'Какое у тебя имя?', 'Как к тебе обращаться?'],
            'responses': ['Меня зовут бот. Просто бот.', 'Зови меня как хочешь. А вообще - я бот.',
                          'Йода просто имя моё. Шучу. Просто бот', 'я - бот', 'Меня зовут бот', 'моё имя - бот']
        },
        'how_are_you': {
            'examples': ['Как дела?', 'Чо как?', 'как настроение?', 'Как ты', 'Чо кого',
                         'ватсап?', 'что с настроением?'],
            'responses': ['Пока не родила))', 'Да ничего, спасибо',
                          'Лучше всех!', 'Просто отлично!', 'Спасибо, всё неплохо', 'Всё круто!']
        },
        'who_are_you': {
            'examples': ['Ты кто?', 'С кем я говорю?', 'кто ты?', 'с кем я разговариваю', 'кто ты?',
                         'что ты такое', 'кто ты такой'],
            'responses': ['я - твой лучший друг и собеседник: бот']
        },
        'eat': {
            'examples': ['хочу есть', 'еда', 'люблю поесть', 'сейчас бы покушать', 'хочу кушать',
                         'люблю еду', 'я голодный'],
            'responses': ['еда - это здорово', 'эх, сейчас бы картошечки жареной']
        },
        'walk': {
            'examples': ['хочу гулять', 'пойду гулять', 'выйду на прогулку', 'прогуляться что-ли', 'пойду на улицу',
                         'хочу на улицу', 'на улице хорошо'],
            'responses': ['Гулять - полезно для здоровья', 'Я бы тоже прогулялся. если бы мог...']
        },
        'music': {
            'examples': ['ты слушаешь музыку?', 'люблю слушать музыку', 'я слушаю музыку', 'моя любимая песня', 'много песен знаешь?',
                         'спою сейчас', 'музыка классная'],
            'responses': ['Спой мне что-нибудь', 'подпеваю тебе мысленно',
                          'ла-ла-ла', 'хоп-хей-ла-ла-лей']
        },
        'weather': {
            'examples': ['Какая погода в МОскве?', 'Какая погода?', 'Погоду не подскажешь?', 'что по погоде?',
                         'Как там с погодой?', 'погода на сеодня', 'какая сегодня погода?'],
            'responses': ['Погода так себе...', 'Да погода сегодня не очень..Как всегда, впрочем',
                          'Да сразу и не ответишь.. Мне отсюда не видно окно. Посмотри сам',
                          'Честно - не знаю. Спроси у Алисы',
                          'Погода - райская! Обожаю дождь со снегом. Или сейчас лето?',
                          'Временами солнечно. Надеюсь, угадал...']
        }

    },

    'failure_phrases': [
        'Я не знаю, что ответить',
        'Не поняла вас',
        'Переформулируйте пожалуйста',
        'Даже не знаю что и сказать...',
        'Ума не приложу - что тебе ответить. Спроси ещё что-нибудь',
        'Перегрузка...Я не справляюсь',
        'Спроси ещё',
        'Извини, не понимаю',

    ]
}


]

# %%
print(len(configs))  # should be 75
# Out:
# 75

# %%
# fix structure

for config in configs:
    if 'intents' not in config:
        config['intents'] = {}
    if 'failure_phrases' not in config:
        config['failure_phrases'] = []

    for intent, data in config['intents'].items():
        if 'examples' not in data:
            print(intent, data)  # shouldn't happens
        if 'responses' not in data:
            print(intent, data)  # shouldn't happens
        
        if any(not isinstance(example, str) for example in data['examples']):
            print(intent, example)  # shouldn't happens
        if any(not isinstance(response, str) for response in data['responses']):
            print(intent, response)  # shouldn't happens

    if any(not isinstance(phrase, str) for phrase in config['failure_phrases']):
        print(intent, phrase)  # shouldn't happens

# %%
# merge intents by names
final_intents = {}

for config in configs:
    for intent, data in config['intents'].items():
        if intent not in final_intents:
            final_intents[intent] = {'examples': [], 'responses': []}
        final_intents[intent]['examples'] += data['examples']
        final_intents[intent]['responses'] += data['responses']

print('Different intent names:', len(final_intents))
# Out:
# Different intent names: 252

# %%
# remove repeats and empty strings
def clear(intents):
    for intent, data in intents.items():
        data['examples'] = list(set(data['examples']))
        data['responses'] = list(set(data['responses']))
        if '' in data['examples']:
            data['examples'].remove('')
        if '' in data['responses']:
            data['responses'].remove('')

clear(final_intents)

# %%
# find intents with different names but same examples
intersecting_pairs = set()

for intent1, data1 in final_intents.items():
    for intent2, data2 in final_intents.items():
        if (intent2, intent1) not in intersecting_pairs and intent1 != intent2 \
                and set(data1['examples']) & set(data2['examples']):
            print(intent1, intent2, set(data1['examples']) & set(data2['examples']))
            intersecting_pairs.add((intent1, intent2))
# Out:
# hello goodbye {'Чао', 'Доброй ночи'}
# hello mood {'Как жизнь?'}
# hello howareyou {'Как жизнь?', 'Как жизнь'}
# hello how_are_you {'Как жизнь?'}
# hello business1 {'Как жизнь?'}
# hello howareyoudoing {'Как жизнь?'}
# hello Smalltalk {'Как жизнь?'}
# thanks standart_answers {'Отлично', 'Ок'}
# thanks adduseranswers {'Отлично'}
# thanks thinks {'Отлично', 'спс', 'Спасибо'}
# thanks Compliments {'Ты лучший'}
# whatcanyoudo name {'кто ты?'}
# whatcanyoudo who_are_you {'кто ты?'}
# whatcanyoudo whatyoudo {'Что ты делаешь?'}
# whatcanyoudo whatyoucando {'Какие у тебя навыки?', 'Что ты можешь', 'Что ты можешь?', 'Что ты умеешь?', 'Что умеешь?', 'Расскажи что умеешь'}
# whatcanyoudo anyquestion {'Ау'}
# whatcanyoudo au {'Ау'}
# name who_are_you {'кто ты?', 'Ты кто?', 'Ты кто', 'Кто ты?'}
# name whoareyou {'Кто ты?', 'Представься', 'Ты кто?', 'ты кто'}
# name name_bot {'имя', 'твоё имя'}
# name who {'Как к тебе обращаться?', 'Как тебя зовут?', 'Кто ты?', 'Ты кто?'}
# ...

# %%
# make fixes

def remove(intent, phrases):
    for phrase in phrases:
        final_intents[intent]['examples'].remove(phrase)

def merge(a, b):
    final_intents[a]['examples'] = list(set(final_intents[a]['examples'] + final_intents[b]['examples']))
    final_intents[a]['responses'] = list(set(final_intents[a]['responses'] + final_intents[b]['responses']))
    final_intents.pop(b)

remove('hello', ['Чао', 'Как жизнь', 'Как жизнь?'])
remove('goodbye', ['Доброй ночи'])
merge('thanks', 'thinks')
remove('thanks', ['Отлично', 'Ок', 'Ты лучший'])
merge('whatcanyoudo', 'whatyoudo')
merge('whatcanyoudo', 'whatyoucando')
remove('whatcanyoudo', ['кто ты?', 'Ау'])
merge('name', 'who_are_you')
merge('name', 'whoareyou')
merge('name', 'name_bot')
merge('name', 'who')
merge('weather', 'wheather')
merge('meaning', 'meaningoflife')
remove('philosophy', ['В чем смысл жизни?'])
merge('hobby', 'love')
merge('how_are_you', 'howayou')
merge('how_are_you', 'howareyou')
merge('how_are_you', 'howdoyoudo')
merge('how_are_you', 'mood')
merge('how_are_you', 'how_is_your_mood')
merge('how_are_you', 'news')
merge('how_are_you', 'whatsup')
merge('how_are_you', 'health')
merge('how_are_you', 'verbalcommun')
merge('how_are_you', 'howru')
merge('how_are_you', 'howareyoudoing')
merge('how_are_you', 'Smalltalk')
merge('how_are_you', 'nastroenie')
merge('how_are_you', 'business1')
merge('how_are_you', 'Feeling well')
merge('how_are_you', 'say')
merge('how_are_you', 'whatdoyoudo')
merge('how_are_you', 'whatsnew')
merge('how_are_you', 'whatareyoudoing')
merge('how_are_you', 'doing')
merge('how_are_you', 'action')
merge('how_are_you', 'howare you')
merge('how_are_you', 'whatareyoudoingnow')
remove('name', ['ты бот', 'Расскажи о себе'])
merge('compliment', 'welldone')


# merge rest automatically
to_be_removed = []
for intent1, data1 in final_intents.items():
    for intent2, data2 in final_intents.items():
        if intent2 not in to_be_removed and intent1 != intent2 and set(data1['examples']) & set(data2['examples']):
            data1['examples'] = list(set(data1['examples'] + data2['examples']))
            data1['responses'] = list(set(data1['responses'] + data2['responses']))
            to_be_removed.append(intent2)
for intent in to_be_removed:
    final_intents.pop(intent)

# %%
# check no more intersections
for intent1, data1 in final_intents.items():
    for intent2, data2 in final_intents.items():
        if intent1 != intent2 and set(data1['examples']) & set(data2['examples']):
            print(intent1, intent2)  # shouldn't happens

# %%
print('Unique intents:', len(final_intents))
# Out:
# Unique intents: 157

# %%
print('Total examples:', sum(len(data['examples']) for data in final_intents.values()))
print('Total responses:', sum(len(data['responses']) for data in final_intents.values()))
# Out:
# Total examples: 923
# Total responses: 954

# %%
# collect failure phrases
failure_phrases = []
for config in configs:
    failure_phrases += config['failure_phrases']
failure_phrases = list(set(failure_phrases))  # remove repeats
print(len(failure_phrases))
print(failure_phrases)
# Out:
# 85
# ...

# %%
# make config
BOT_CONFIG = {
    'threshold': 0.6,
    'intents': final_intents,
    'failure_phrases': failure_phrases
}
print(BOT_CONFIG)
# Out:
# {'threshold': 0.6, 'intents': {'hello': {'examples': ['прывит', 'Привет', 'Приветствую', 'Куку', 'Добрый день', 'Салам', 'hello', 'Здарова', 'ghbdtn', 'бонжур', '✋', 'Хэй!', 'Добрейшего дня', 'СаламДоброе утро', 'Хелло', 'Здорово', 'Вечер в Хату', 'ола', 'Доброе утро', 'q', 'здарова', 'Добрый вечер', 'Здоровченко', 'Здрасьте', 'Гуден таг', 'Хеллоу', '✌️', 'даров', 'Привет, медвед', 'hallo', 'прив', 'Салям', 'Здраствуйте!', 'Салам Алейкум', 'Хаюшки', 'Приветули', 'Шалом', 'Хаюшки!', 'ку', 'барев', 'Хей', 'Здравствуйте', 'Нихао', 'Салем', 'Салют', 'Йоу', 'День добрый', 'Ола', 'здрастуйтэ', 'Алоха', 'Доброго времени суток', 'Приветики', 'Дратути', 'Здравствуйте!', 'хай', 'Прив', 'Ку', 'Доброй ночи', 'Хай', 'Бонжур', 'привет', 'Коннитива', 'хи', 'Трям', 'Салют!', 'Здорова', 'Здарово', 'Приветик', 'Здраствуй', 'Приветушки', 'Денечка вам', 'добрый', 'hi', '🙌', 'Здравствуй', 'Привки', 'сэрвус', 'Здорово!', 'Салом алейкум', 'хайса'], 'responses': ['Приветствую)', 'И тебе привет!', 'прывит', 
# ...

# %%
# check accuracy on final config

# %%
dataset = []  # [[example, intent], ...]

for intent, intent_data in BOT_CONFIG['intents'].items():
    for example in intent_data['examples']:
        dataset.append([example, intent])

X_text = [x for x, y in dataset]
y = [y for x, y in dataset]

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(X_text)

scores = []

for _ in range(100):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
    clf = LogisticRegression()
    clf.fit(X_train, y_train)
    score = clf.score(X_test, y_test)
    scores.append(score)

print(sum(scores) / 100)
# Out:
# 0.3204332129963904
